# %%
# %matplotlib inline
import matplotlib
import seaborn as sns
matplotlib.rcParams['savefig.dpi'] = 144

# %%
from static_grader import grader

# %% [markdown]
# # PW Miniproject
# ## Introduction
#
# The objective of this miniproject is to exercise your ability to use basic Python data structures, define functions, and control program flow. We will be using these concepts to perform some fundamental data wrangling tasks such as joining data sets together, splitting data into groups, and aggregating data into summary statistics.
# **Please do not use `pandas` or `numpy` to answer these questions.**
#
# We will be working with medical data from the British NHS on prescription drugs. Since this is real data, it contains many ambiguities that we will need to confront in our analysis. This is commonplace in data science, and is one of the lessons you will learn in this miniproject.

# %% [markdown]
# ## Downloading the data
#
# We first need to download the data we'll be using from Amazon S3:

# %%
# %%bash
# mkdir pw-data
# wget http://dataincubator-wqu.s3.amazonaws.com/pwdata/201701scripts_sample.json.gz -nc -P ./pw-data
# wget http://dataincubator-wqu.s3.amazonaws.com/pwdata/practices.json.gz -nc -P ./pw-data
# Out:
# mkdir: cannot create directory ‘pw-data’: File exists
# File ‘./pw-data/201701scripts_sample.json.gz’ already there; not retrieving.
#
# File ‘./pw-data/practices.json.gz’ already there; not retrieving.

# %% [markdown]
# ## Loading the data
#
# The first step of the project is to read in the data. We will discuss reading and writing various kinds of files later in the course, but the code below should get you started.

# %%
import gzip
import simplejson as json

# %%
with gzip.open('./pw-data/201701scripts_sample.json.gz', 'rb') as f:
    scripts = json.load(f)

with gzip.open('./pw-data/practices.json.gz', 'rb') as f:
    practices = json.load(f)

# %% [markdown]
# This data set comes from Britain's National Health Service. The `scripts` variable is a list of prescriptions issued by NHS doctors. Each prescription is represented by a dictionary with various data fields: `'practice'`, `'bnf_code'`, `'bnf_name'`, `'quantity'`, `'items'`, `'nic'`, and `'act_cost'`.

# %%
scripts[:2]
# Out:
# [{'bnf_code': '0101010G0AAABAB',
#   'items': 2,
#   'practice': 'N81013',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 5.98,
#   'act_cost': 5.56,
#   'quantity': 1000},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'N81013',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.95,
#   'act_cost': 1.82,
#   'quantity': 500}]

# %% [markdown]
# A [glossary of terms](http://webarchive.nationalarchives.gov.uk/20180328130852tf_/http://content.digital.nhs.uk/media/10686/Download-glossary-of-terms-for-GP-prescribing---presentation-level/pdf/PLP_Presentation_Level_Glossary_April_2015.pdf/) and [FAQ](http://webarchive.nationalarchives.gov.uk/20180328130852tf_/http://content.digital.nhs.uk/media/10048/FAQs-Practice-Level-Prescribingpdf/pdf/PLP_FAQs_April_2015.pdf/) is available from the NHS regarding the data. Below we supply a data dictionary briefly describing what these fields mean.
#
# | Data field |Description|
# |:----------:|-----------|
# |`'practice'`|Code designating the medical practice issuing the prescription|
# |`'bnf_code'`|British National Formulary drug code|
# |`'bnf_name'`|British National Formulary drug name|
# |`'quantity'`|Number of capsules/quantity of liquid/grams of powder prescribed|
# | `'items'`  |Number of refills (e.g. if `'quantity'` is 30 capsules, 3 `'items'` means 3 bottles of 30 capsules)|
# |  `'nic'`   |Net ingredient cost|
# |`'act_cost'`|Total cost including containers, fees, and discounts|

# %% [markdown]
# The `practices` variable is a list of member medical practices of the NHS. Each practice is represented by a dictionary containing identifying information for the medical practice. Most of the data fields are self-explanatory. Notice the values in the `'code'` field of `practices` match the values in the `'practice'` field of `scripts`.

# %%
practices[:2]
# Out:
# [{'code': 'A81001',
#   'name': 'THE DENSHAM SURGERY',
#   'addr_1': 'THE HEALTH CENTRE',
#   'addr_2': 'LAWSON STREET',
#   'borough': 'STOCKTON ON TEES',
#   'village': 'CLEVELAND',
#   'post_code': 'TS18 1HU'},
#  {'code': 'A81002',
#   'name': 'QUEENS PARK MEDICAL CENTRE',
#   'addr_1': 'QUEENS PARK MEDICAL CTR',
#   'addr_2': 'FARRER STREET',
#   'borough': 'STOCKTON ON TEES',
#   'village': 'CLEVELAND',
#   'post_code': 'TS18 2AW'}]

# %% [markdown]
# In the following questions we will ask you to explore this data set. You may need to combine pieces of the data set together in order to answer some questions. Not every element of the data set will be used in answering the questions.

# %% [markdown]
# ## Question 1: summary_statistics
#
# Our beneficiary data (`scripts`) contains quantitative data on the number of items dispensed (`'items'`), the total quantity of item dispensed (`'quantity'`), the net cost of the ingredients (`'nic'`), and the actual cost to the patient (`'act_cost'`). Whenever working with a new data set, it can be useful to calculate summary statistics to develop a feeling for the volume and character of the data. This makes it easier to spot trends and significant features during further stages of analysis.
#
# Calculate the sum, mean, standard deviation, and quartile statistics for each of these quantities. Format your results for each quantity as a list: `[sum, mean, standard deviation, 1st quartile, median, 3rd quartile]`. We'll create a `tuple` with these lists for each quantity as a final result.

# %%
from statistics import median
def describe(key):

    #total = 0
    #avg = 0
    #s = 0
    #q25 = 0
    #med = 0
    #q75 = 0
    total = 0.0
    for i in scripts:
        total = total + float(i[key])
    
    avg = 0.0
    for i in scripts:
        avg = total/(len(scripts))
    
    s = 0.0
    n = 0.0
    for i in scripts:
        n += (i[key] - avg)**2
        s = (n/(len(scripts)))**0.5

    lst = []
    for x in scripts:
        lst.append(x[key])
    sorted_list = sorted(lst)
    q25 = median(sorted_list[:len(lst)//2])
    med = median(lst)
    q75 = median(sorted_list[len(lst)//2:])
    

    return (total, avg, s, q25, med, q75)

# %%
def summary():
    result = [('items', describe('items')),
               ('quantity', describe('quantity')),
               ('nic', describe('nic')),
               ('act_cost', describe('act_cost'))]
    return result

# %%
keys = scripts
summary()
# Out:
# [('items', (4410054.0, 11.522744731217633, 33.11216633980368, 1, 3.0, 8)),
#  ('quantity',
#   (316356836.0, 826.5883059943667, 3872.1810146096263, 30, 120.0, 466)),
#  ('nic',
#   (29048309.790000338,
#    75.89844899484315,
#    197.5728266277507,
#    7.7,
#    22.62,
#    65.94)),
#  ('act_cost',
#   (27053937.599999707,
#    70.68748295124895,
#    183.26731895303854,
#    7.25,
#    21.24,
#    61.53))]

# %%
grader.score.pw__summary_statistics(summary)
# Out:
# ==================
# Your score:  1.0
# ==================

# %% [markdown]
# ## Question 2: most_common_item
#
# Often we are not interested only in how the data is distributed in our entire data set, but within particular groups -- for example, how many items of each drug (i.e. `'bnf_name'`) were prescribed? Calculate the total items prescribed for each `'bnf_name'`. What is the most commonly prescribed `'bnf_name'` in our data?
#
# To calculate this, we first need to split our data set into groups corresponding with the different values of `'bnf_name'`. Then we can sum the number of items dispensed within in each group. Finally we can find the largest sum.
#
# We'll use `'bnf_name'` to construct our groups. You should have *5619* unique values for `'bnf_name'`.

# %%
bnf_names = set([x['bnf_name'] for x in scripts])
assert(len(bnf_names) == 5619)

# %% [markdown]
# We want to construct "groups" identified by `'bnf_name'`, where each group is a collection of prescriptions (i.e. dictionaries from `scripts`). We'll construct a dictionary called `groups`, using `bnf_names` as the keys. We'll represent a group with a `list`, since we can easily append new members to the group. To split our `scripts` into groups by `'bnf_name'`, we should iterate over `scripts`, appending prescription dictionaries to each group as we encounter them.

# %%
groups = {name: [] for name in bnf_names}
for script in scripts:
    # INSERT ...
    groups[script['bnf_name']].append(script['items'])

# %% [markdown]
# Now that we've constructed our groups we should sum up `'items'` in each group and find the `'bnf_name'` with the largest sum. The result, `max_item`, should have the form `[(bnf_name, item total)]`, e.g. `[('Foobar', 2000)]`.

# %%
#max_item = [("", 0)]

def most_common_item():
    max_dict ={}
    for k,v in groups.items():
        max_dict[k] = sum(v)
    max_item = (max(max_dict.keys(), key=(lambda k: max_dict[k])) , max_dict[max(max_dict.keys(), key=(lambda k: max_dict[k]))])
    return [max_item]

# %%
max_item = most_common_item()

# %% [markdown]
# **TIP:** If you are getting an error from the grader below, please make sure your answer conforms to the correct format of `[(bnf_name, item total)]`.

# %%
grader.score.pw__most_common_item(most_common_item())
# Out:
# ==================
# Error!
# You have been rate limited for exceeding the limit of 1 per 1 second.
# Please slow down your submission rate.
# ==================

# %% [markdown]
# **Challenge:** Write a function that constructs groups as we did above. The function should accept a list of dictionaries (e.g. `scripts` or `practices`) and a tuple of fields to `groupby` (e.g. `('bnf_name')` or `('bnf_name', 'post_code')`) and returns a dictionary of groups. The following questions will require you to aggregate data in groups, so this could be a useful function for the rest of the miniproject.

# %%
def group_by_field(data, fields):
    names = {tuple(dict_[field] for field in fields)
            for dict_ in data}
    groups = {name: [] for name in names}
    for dict_ in data:
        name = tuple(dict_[field] for field in fields)
        groups[name].append(dict_)
    return groups

# %%
groups = group_by_field(scripts, ('bnf_name',))
test_max_item = [max(
    (sum(member['items'] for member in group), name[0])
    for name , group in list(groups.items())
)[::-1]]

assert test_max_item == max_item

# %% [markdown]
# ## Question 3: postal_totals
#
# Our data set is broken up among different files. This is typical for tabular data to reduce redundancy. Each table typically contains data about a particular type of event, processes, or physical object. Data on prescriptions and medical practices are in separate files in our case. If we want to find the total items prescribed in each postal code, we will have to _join_ our prescription data (`scripts`) to our clinic data (`practices`).
#
# Find the total items prescribed in each postal code, representing the results as a list of tuples `(post code, total items prescribed)`. Sort your results ascending alphabetically by post code and take only results from the first 100 post codes. Only include post codes if there is at least one prescription from a practice in that post code.
#
# **NOTE:** Some practices have multiple postal codes associated with them. Use the alphabetically first postal code.

# %% [markdown]
# We can join `scripts` and `practices` based on the fact that `'practice'` in `scripts` matches `'code'` in `practices'`. However, we must first deal with the repeated values of `'code'` in `practices`. We want the alphabetically first postal codes.

# %%
practice_postal = {}
for practice in practices:
    if practice['code'] in practice_postal:
        if practice['post_code'] < practice_postal[practice['code']]:
            practice_postal[practice['code']] = practice['post_code']
        else:
            pass
    else:
        practice_postal[practice['code']] = practice['post_code']

# %% [markdown]
# **Challenge:** This is an aggregation of the practice data grouped by practice codes. Write an alternative implementation of the above cell using the `group_by_field` function you defined previously.

# %%
assert practice_postal['K82019'] == 'HP21 8TR'

# %% [markdown]
# **Challenge:** This is an aggregation of the practice data grouped by practice codes. Write an alternative implementation of the above cell using the `group_by_field` function you defined previously.

# %%
assert practice_postal['K82019'] == 'HP21 8TR'

# %% [markdown]
# Now we can join `practice_postal` to `scripts`.

# %%
joined = scripts[:]
for script in joined:
    script['post_code'] = practice_postal[script['practice']]

# %% [markdown]
# Finally we'll group the prescription dictionaries in `joined` by `'post_code'` and sum up the items prescribed in each group, as we did in the previous question.

# %%
items_by_post = []
for script in joined:
    items_by_post.append((script['post_code']))

# %%
def postal_totals():
    groups={post_code: [] for post_code in items_by_post}

    for script in joined:
        groups[script['post_code']].append(script['items'])

    for group in groups.items():
        groups[group[0]]=sum(group[1])

    sortes_postals = sorted(groups.items(), key=lambda tup: tup[0])
    return sortes_postals[:100]

# %%
items_by_post[:1]
# Out:
# ['SK11 6JL']

# %%
#postal_totals = items_by_post[:100]

# %%
#postal_totals = [('B11 4BW', 20673)] * 100

grader.score.pw__postal_totals(postal_totals())
# Out:
# ==================
# Your score:  1.0
# ==================

# %% [markdown]
# ## Question 4: items_by_region
#
# Now we'll combine the techniques we've developed to answer a more complex question. Find the most commonly dispensed item in each postal code, representing the results as a list of tuples (`post_code`, `bnf_name`, amount dispensed as proportion of total). Sort your results ascending alphabetically by post code and take only results from the first 100 post codes.
#
# **NOTE:** We'll continue to use the `joined` variable we created before, where we've chosen the alphabetically first postal code for each practice. Additionally, some postal codes will have multiple `'bnf_name'` with the same number of items prescribed for the maximum. In this case, we'll take the alphabetically first `'bnf_name'`.

# %% [markdown]
# Now we need to calculate the total items of each `'bnf_name'` prescribed in each `'post_code'`. Use the techniques we developed in the previous questions to calculate these totals. You should have 141196 `('post_code', 'bnf_name')` groups.

# %%
#max_item_by_post = [sorted(group, key=itemgetter('total'), reverse=True)[0]
 #                  for group in list(total_items_by_post.values())]

# %%
items_by_post.sort()

# %%
dict(items_by_post)

# %%
items_by_region = []

for item in max_item_by_post:
    numerator = item['total']
    denominator = dict(items_by_post)[item['post_code']]
    proportion = numerator / denominator
    result = (item['post_code'], item['bnf_name'], proportion)
    items_by_region.append(result)

# %%
items_by_region[0]

# %%
items_by_region = sorted(items_by_region)[:100 ]

# %%
items_by_region[:1]

# %%
grader.score.pw__items_by_region(items_by_region)

# %%
total_items_by_bnf_post = {}
for key, group in list(group_by_field(joined, ('post_code', 'bnf_name')).items()):
    items_total = sum(d['items'] for d in group)
    total_items_by_bnf_post[key] = items_total

# %%
total_items_by_bnf_post
# Out:
# {('LS9 9EF', 'Sod Algin/Pot Bicarb_Susp S/F'): 79,
#  ('WS3 3JP', 'Felodipine_Tab 2.5mg M/R'): 37,
#  ('OL4 1YN', 'K-Soft Long 10cm x 4.5m M/Layer Compress'): 8,
#  ('GL1 3PX', 'Clomipramine HCl_Cap 25mg'): 4,
#  ('SE15 5LJ', 'Candesartan Cilexetil_Tab 8mg'): 49,
#  ('NE24 1DX', 'Lansoprazole_Cap 30mg (E/C Gran)'): 1350,
#  ('SS9 5UU', 'Mirtazapine_Orodisper Tab 45mg'): 15,
#  ('KT6 6EZ', 'Cetraben_Bath Oil'): 5,
#  ('NN16 8DN', 'Movelat_Crm'): 5,
#  ('TW3 3LN', 'Irbesartan_Tab 75mg'): 62,
#  ('WA7 1AB', 'Aspirin_Tab 75mg'): 20,
#  ('TW3 3LN', 'Co-Codamol_Tab 8mg/500mg'): 70,
#  ('B70 7AW', 'Priadel_Tab 200mg'): 14,
#  ('CV1 4FS', 'Viscotears_Liq Gel 2mg/g'): 16,
#  ('TW8 8DS', 'Donepezil HCl_Tab 10mg'): 30,
#  ('TS17 0EE', 'Sitagliptin_Tab 100mg'): 139,
#  ('BB8 0JZ', 'Buccolam_Oromuc Soln 10mg/2ml Oral Pfs'): 2,
#  ('WV13 2DR', 'Betameth Val/Fusidic Acid_Crm 0.1%/2%'): 40,
#  ('CW1 3AW', 'Ranolazine_Tab 750mg M/R'): 3,
#  ('KT6 6EZ', 'Maxitrol_Eye Dps'): 7,
#  ('NE24 1DX', 'Cinchocaine HCl/Hydrocort_Suppos 5mg/5mg'): 8,
#  ('BB7 2JG', 'Naproxen_Tab E/C 250mg'): 7,
#  ('KT6 6EZ', 'Pregabalin_Cap 50mg'): 27,
#  ('B70 7AW', 'Bisoprolol Fumar_Tab 10mg'): 57,
#  ('LN2 2JP', 'Paracet_Oral Susp Paed 120mg/5ml S/F'): 6,
#  ('PL7 1AD', 'Shortec_Cap 5mg'): 23,
#  ('TW3 3LN', 'Lodoxamide Trometamol_Eye Dps 0.1%'): 2,
#  ('W10 6DZ', 'Salivix Pastil (App)'): 2,
#  ('TS1 2NX', 'Trulicity_Inj 1.5mg/0.5ml Pf Pen'): 6,
#  ('BL1 8TU', 'Candesartan Cilexetil_Tab 32mg'): 32,
#  ('SE1 6JP', 'Sotalol HCl_Tab 80mg'): 6,
#  ('TS3 6AL', 'BuTrans_Transdermal Patch 10mcg/hr'): 9,
#  ('YO16 4LZ', 'Nifedipine_Cap 10mg'): 4,
#  ('WA10 2DJ', 'Zerobase Crm (Appl)'): 37,
#  ('TW8 8DS', 'Ins NovoRapid_FlexPen 100u/ml 3ml Pf Pen'): 32,
#  ('PL7 1AD', 'Eucerin_Intensive Lot 10%'): 2,
#  ('FY2 0JG', 'Salbutamol_Inh Soln 5mg/2.5ml Ud'): 8,
#  ('TS24 7PW', 'Sevredol_Tab 10mg'): 3,
#  ('BB8 0JZ', 'Aveeno_Crm'): 163,
#  ('L31 0DJ', 'Sod Valpr_Tab 100mg'): 2,
#  ('S65 1DA', 'Docusate Sod_Oral Soln 50mg/5ml S/F'): 18,
#  ('CW7 1AT', 'Nexplanon_Implant 68mg'): 11,
#  ('S65 1DA', 'Apixaban_Tab 2.5mg'): 54,
#  ('KT6 6EZ', 'Tolterodine_Tab 2mg'): 18,
#  ('NE37 2PU', 'Zetuvit Plus 10cm x 20cm Super-Absorb Dr'): 4,
#  ('LE5 3GH', 'Synalar_Oint 1/4 Strgh 0.00625%'): 5,
#  ('GL50 4DP', 'Fluticasone/Salmeterol_Inh 250/25mcg120D'): 15,
#  ('DA11 8BZ', 'Budesonide/Formoterol Inh B/A 200/6(120D'): 10,
#  ('TR1 2JA', 'Sitagliptin_Tab 25mg'): 7,
#  ('CH65 6TG', 'Hollister_Adapt Lubri Deod Sach'): 2,
#  ('TS3 6AL', 'Multi-Pack Ster Dress Pack'): 13,
#  ('HU7 4DW', 'Mebeverine HCl_Cap 200mg M/R'): 32,
#  ('N9 7HD', 'Fusidic Acid_Crm 2%'): 31,
#  ('BL3 5HP', 'Carbimazole_Tab 20mg'): 3,
#  ('BH23 3AF', 'Levonorgest_Tab 1.5mg'): 9,
#  ('BL9 0NJ', 'Airomir_Autohaler 100mcg (200 D) CFF'): 18,
#  ('BB3 1PY', 'Desmopressin Acet_Tab 200mcg'): 5,
#  ('TS1 2NX', 'Nutramigen 1 LIPIL_Pdr'): 5,
#  ('NE38 7NQ', 'Cosmopor E 5cm x 7.2cm Adh Dress Pfa'): 8,
#  ('HU7 4DW', 'Longtec_Tab 10mg M/R'): 40,
#  ('LS9 9EF', 'Senna_Tab 15mg'): 4,
#  ('SK11 6JL', 'Metronidazole_Tab 400mg'): 54,
#  ('B21 9RY', 'Liq Paraf Light_Gel 70%'): 9,
#  ('PL7 1AD', 'Fresubin Energy Fibre_Liq (6 Flav)'): 4,
#  ('BB7 2JG', 'Benzoyl Per/Clindamycin Phos_Gel 5%/1%'): 6,
#  ('FY4 1TJ', 'Fluticasone/Salmeterol_Inh 100/50mcg 60D'): 9,
#  ('NG7 3GW', 'Pentasa_Gran Sach 1g M/R'): 2,
#  ('NG7 3GW', 'Betameth Val/Fusidic Acid_Crm 0.1%/2%'): 5,
#  ('FY5 2TZ', 'Olanzapine_Tab 10mg'): 7,
#  ('BB3 1PY', 'Quinine Sulf_Tab 200mg'): 62,
#  ('HU7 4DW', 'Chloramphen_Eye Dps 0.5%'): 45,
#  ('S65 1DA', 'Atenolol_Tab 50mg'): 331,
#  ('CH1 4DS', 'Atenolol_Tab 50mg'): 119,
#  ('BL1 8TU', 'Trimipramine Mal_Cap 50mg'): 3,
#  ('BB9 7SR', 'H & R_Proshield Foam & Spy Skin Cleanser'): 4,
#  ('SK6 1ND', 'Seretide 125_Evohaler 125mcg/25mcg(120D)'): 10,
#  ('BB11 2DL', 'Nicorandil_Tab 20mg'): 60,
#  ('CW1 3AW', 'Etoricoxib_Tab 60mg'): 3,
#  ('PL7 1AD', 'Nutramigen 2 + LGG_Pdr'): 3,
#  ('CW1 3AW', 'Terbinafine HCl_Tab 250mg'): 31,
#  ('B23 6DJ', 'Sod Feredetate_Oral Soln 190mg/5ml S/F'): 11,
#  ('BH18 8EE', 'Comfifast 10.75cm x 1m (Yellow)Stkntte E'): 2,
#  ('CW1 3AW', 'Respond_OstoMart OstoPEEL Blkberry NoSti'): 5,
#  ('SK11 6JL', 'Lansoprazole_Orodisper Tab 15mg'): 21,
#  ('B11 4BW', 'Fortisip Bottle_Liq (8 Flav)'): 80,
#  ('NE38 7NQ', 'Memantine HCl_Tab 10mg'): 14,
#  ('NG7 3GW', 'Pregabalin_Cap 75mg'): 14,
#  ('N9 7HD', 'Oxybutynin HCl_Tab 10mg M/R'): 5,
#  ('TW3 3LN', 'Nortriptyline_Tab 10mg'): 18,
#  ('S74 9AF', 'Co-Codamol_Tab 30mg/500mg'): 457,
#  ('N9 7HD', 'Orlistat_Cap 120mg'): 35,
#  ('LE10 1DS', 'Fluclox Sod_Cap 500mg'): 119,
#  ('SK11 6JL', 'Glutafin_G/F Fibre Fusilli'): 3,
#  ('TN24 0GP', 'Venlafaxine_Cap 75mg M/R'): 3,
#  ('DN22 7XF', 'Amoxicillin_Oral Susp 250mg/5ml S/F'): 18,
#  ('SM3 8EP', 'Sebco_Oint'): 2,
#  ('CT11 8AD', 'K-Soft Long 10cm x 4.5m M/Layer Compress'): 8,
#  ('ST8 6AG', 'Simvastatin_Tab 10mg'): 32,
#  ('L31 0DJ', 'Sandrena_Gel Sach 1mg/1g'): 3,
#  ('FY7 8GU', 'Medroxyprogest Acet_Tab 10mg'): 5,
#  ('BL9 0NJ', 'Tildiem LA 300_Cap 300mg'): 2,
#  ('TS23 2DG', 'Fentanyl_Transdermal Patch 12mcg/hr'): 16,
#  ('M26 2SP', 'Salbutamol_Inha 100mcg (200 D) CFF'): 621,
#  ('OL9 7AY', 'Sitagliptin_Tab 100mg'): 165,
#  ('ST3 6AB', 'Coal Tar_Ext Shampoo 2%'): 4,
#  ('N9 7HD', 'White Soft Paraf/Liq Paraf_(S) 50%/50%'): 43,
#  ('LE5 3GH', 'Tacrolimus_Oint 0.1%'): 5,
#  ('TS10 4NW', 'Alfuzosin HCl_Tab 10mg M/R'): 26,
#  ('SS8 0JA', 'Ventolin_Evohaler 100mcg (200 D)'): 510,
#  ('W10 6DZ', 'Co-Amoxiclav_Susp 125mg/31mg/5ml S/F'): 4,
#  ('GL50 4DP', 'Ezetimibe_Tab 10mg'): 119,
#  ('TS1 2NX', 'Tiotropium_Pdr For Inh Cap 18mcg + Dev'): 23,
#  ('SR4 7XF', 'Aspirin_Tab E/C 75mg'): 81,
#  ('B11 4BW', 'Aquamax Crm (Appl)'): 2,
#  ('W10 6DZ', 'Pyridox HCl_Tab 50mg'): 7,
#  ('NE38 7NQ', 'Irbesartan_Tab 150mg'): 81,
#  ('CH1 4DS', 'Calcichew D3 Fte_Tab Chble'): 161,
#  ('CW1 3AW', 'Amiodarone HCl_Tab 100mg'): 7,
#  ('SK6 1ND', 'Rivastigmine_Cap 3mg'): 7,
#  ('SR4 7XF', 'Balneum_Bath Oil 84.75%'): 5,
#  ('SM6 0HY', 'Amiloride HCl_Tab 5mg'): 3,
#  ('NE10 9QG', 'BD Microfine+ Needles Pen Inj Screw On 5'): 11,
#  ('SR5 2LT', 'Cetraben Crm 500g'): 14,
#  ('DN34 4GB', 'Lymecycline_Cap 408mg'): 19,
#  ('S63 9EH', 'Propranolol HCl_Cap 160mg M/R'): 3,
#  ('BD3 8QH', 'Ibuprofen_Oral Susp 100mg/5ml S/F'): 44,
#  ('TS3 6AL', 'Citalopram HCl_Oral Dps 40mg/ml S/F'): 2,
#  ('LN2 2JP', 'Moxonidine_Tab 300mcg'): 4,
#  ('WA9 1LN', 'Verapamil HCl_Tab 40mg'): 6,
#  ('WS3 3JP', 'Sustanon_Inj 250mg/1ml Amp'): 2,
#  ('SS13 3HQ', 'Spironol_Tab 25mg'): 87,
#  ('BH18 8EE', 'Anastrozole_Tab 1mg'): 51,
#  ('TS3 6AL', 'Ins Humalog_100u/ml 3ml Cart'): 6,
#  ('BL9 0NJ', 'Oilatum_Emollient'): 8,
#  ('OL1 1NL', 'Clobetasol Prop_Shampoo 500mcg/g'): 3,
#  ('NE24 1DX', 'Ropinirole HCl_Tab 2mg M/R'): 6,
#  ('FY2 0JG', 'Venlafaxine_Tab 37.5mg'): 35,
#  ('TS24 7PW', 'Ciprofloxacin_Eye Dps 0.3%'): 9,
#  ('SK6 1ND', '3m Health Care_Cavilon No Sting Barrier'): 4,
#  ('LE10 1DS', 'Co-Beneldopa_Cap 12.5mg/50mg'): 7,
#  ('LE10 1DS', 'Tubifast 2-Way Stch 7.5cm x 5m (Blue) St'): 3,
#  ('L7 6HD', 'Desogestrel_Tab 75mcg'): 21,
#  ('B70 7AW', 'Zopiclone_Tab 3.75mg'): 105,
#  ('NE24 1DX', 'Levetiracetam_Oral Soln 500mg/5ml S/F'): 7,
#  ('LE18 2EW', 'Sumatriptan_Tab 100mg'): 14,
#  ('CB9 8HF', 'Modafinil_Tab 100mg'): 3,
#  ('WN2 5NG', 'Phenytoin_Sod Cap 100mg'): 4,
#  ('SK6 1ND', 'Dermovate_Oint 0.05%'): 3,
#  ('S74 9AF', 'Bisacodyl_Tab E/C 5mg'): 70,
#  ('L5 0QW', 'Coloplast_Trident T1 Leg Bag 750ml Long'): 2,
#  ('OL1 1NL', 'Depo-Provera_Inj 150mg/ml 1ml Pfs'): 27,
#  ('NE37 2PU', 'Lyrica_Cap 300mg'): 10,
#  ('SS0 7AF', 'Escitalopram_Tab 5mg'): 5,
#  ('B11 4BW', 'Pravastatin Sod_Tab 40mg'): 10,
#  ('BH18 8EE', 'Sinemet-Plus_Tab 125mg'): 11,
#  ('OL9 7AY', 'Optive 0.5% Carmellose Eye Dps 10ml'): 8,
#  ('LE5 3GH', 'Propranolol HCl_Cap 80mg M/R'): 18,
#  ('YO16 4LZ', 'Carvedilol_Tab 6.25mg'): 38,
#  ('L5 0QW', 'Bepanthen_Nappy Care Oint 5%'): 3,
#  ('SM6 0HY', 'Ropinirole HCl_Tab 2mg M/R'): 7,
#  ('FY5 2TZ', 'Fenofibrate_Tab 160mg (Micronised)'): 4,
#  ('B21 9RY', 'Salic Acid/Lactic Acid_Gel 11%/4%'): 7,
#  ('WA7 1AB', 'Ferr Glucon_Tab 300mg'): 2,
#  ('TS10 4NW', 'Salamol E-Breathe_Inh 100mcg (200 D) CFF'): 24,
#  ('BB3 1PY', 'Calamine_Lot'): 2,
#  ('PL7 1AD', 'Bicalutamide_Tab 150mg'): 4,
#  ('CV1 4FS', 'Olanzapine_Tab 5mg'): 11,
#  ('SS13 3HQ', 'Cathejell Lidocaine C Lubricant Gel 12.5'): 7,
#  ('M26 2SP', 'Betahistine HCl_Tab 16mg'): 50,
#  ('WD18 0JP', 'Saline Steripoule_Inh Soln 0.9% 2.5ml Ud'): 3,
#  ('TS23 2DG', 'Ibuprofen_Gel 10%'): 38,
#  ('SK6 1ND', 'Voltarol Emulgel_Aq Gel 1.16%'): 8,
#  ('WN3 5HL', 'Bisacodyl_Tab E/C 5mg'): 12,
#  ('SR5 2LT', 'Pregabalin_Cap 100mg'): 30,
#  ('BH23 3AF', 'ReplensMD Vag Moist 35g Tube'): 6,
#  ('CH1 4DS', 'Glucotabs_Tab (Tangy Orange)'): 3,
#  ('BD3 8QH', 'Buccolam_Oromuc Soln 10mg/2ml Oral Pfs'): 3,
#  ('CW1 3AW', 'Mesalazine_Tab G/R 1.2g M/R'): 3,
#  ('BL9 0NJ', 'Lyrica_Cap 300mg'): 18,
#  ('L5 0QW', 'Baclofen_Tab 10mg'): 34,
#  ('LA1 1PN', 'Aspen_Sorbaderm Barrier Crm 92g'): 7,
#  ('NE38 7NQ', 'T & R Sod Bicarb Ear Dps 5% Ear Wax Soft'): 3,
#  ('NE38 7NQ', 'Seretide 500_Accuhaler 500mcg/50mcg(60D)'): 105,
#  ('BB9 7SR', 'Hylo-Tear Sod Hyaluronate Eye Dps 0.1% P'): 22,
#  ('BB8 0JZ', 'Aveeno_Skin Relief Moisturising Lot Shea'): 4,
#  ('TS17 0EE', 'Amoxicillin_Cap 250mg'): 3,
#  ('TS23 2DG', 'Macrogol_Co Oral Pdr Sach S/F'): 140,
#  ('BH18 8EE', 'Seretide 250_Evohaler 250mcg/25mcg(120D)'): 5,
#  ('CV1 4FS', 'Naseptin_Crm'): 14,
#  ('CH65 6TG', 'Methylphenidate HCl_Tab 10mg'): 8,
#  ('LE5 3GH', 'Co-Codamol_Cap 15mg/500mg'): 4,
#  ('HA0 4UZ', 'Levetiracetam_Tab 250mg'): 6,
#  ('SM6 0HY', 'Anusol HC_Oint'): 3,
#  ('PL7 1AD', 'Ins NovoRapid_FlexPen 100u/ml 3ml Pf Pen'): 40,
#  ('DA1 2HA', 'Bendroflumethiazide_Tab 2.5mg'): 324,
#  ('CT11 8AD', 'Glandosane A/Spy 50ml (App)'): 6,
#  ('CH65 6TG', 'Fybogel_Gran Sach 3.5g Orange G/F S/F'): 10,
#  ('BL1 8TU', 'Oxytetracycline_Tab 250mg'): 12,
#  ('M30 0NU', 'Calceos_Tab Chble 500mg/400u'): 3,
#  ('TW3 3LN', 'Valsartan_Cap 160mg'): 4,
#  ('FY4 1TJ', 'Mupirocin_Nsl Oint 2%'): 2,
#  ('CH65 6TG', 'Citalopram Hydrob_Tab 40mg'): 40,
#  ('FY7 8GU', 'Verapamil HCl_Tab 40mg'): 4,
#  ('TN34 1BA', 'Clopixol_Tab 25mg'): 2,
#  ('OL11 1DN', 'Dutasteride_Cap 500mcg'): 4,
#  ('WA10 2DJ', 'Trimovate_Crm'): 3,
#  ('KT6 6EZ', 'Clinitas Carbomer Eye Gel'): 2,
#  ('L5 0QW', 'Dabigatran Etexilate_Cap 150mg'): 4,
#  ('TS17 0EE', 'Fostair_Inh 200mcg/6mcg (120D) CFF'): 24,
#  ('BB11 2DL', 'Calc Carb_Tab Chble 1.25g (500mg) S/F'): 8,
#  ('BB8 0JZ', 'Ramipril_Cap 5mg'): 444,
#  ('SS9 5UU', 'Contour TS (Reagent)_Strips'): 5,
#  ('LN2 2JP', 'Lido/Hydrocort Acet_Oint 5%/0.275%'): 5,
#  ('LN2 2JP', 'Gabapentin_Cap 400mg'): 16,
#  ('NE38 7NQ', 'Simvastatin_Tab 80mg'): 14,
#  ('DN34 4GB', 'Pregabalin_Cap 150mg'): 30,
#  ('BB11 2DL', 'Salic Acid/Lactic Acid_Gel 11%/4%'): 6,
#  ('DN22 7XF', 'Celecoxib_Cap 200mg'): 6,
#  ('CV1 4FS', 'Hydrocort/Miconazole Nit_Crm 1%/2%'): 48,
#  ('SM6 0HY', 'Risperidone_Tab 1mg'): 25,
#  ('ST3 6AB', 'Fenofibrate_Cap 200mg (Micronised)'): 9,
#  ('DA11 8BZ', 'Tegretol Prolonged Release_Tab 400mg M/R'): 10,
#  ('WA7 1AB', 'Valsartan_Cap 160mg'): 2,
#  ('TS17 0EE', 'Co-Beneldopa_Tab Disper 25mg/100mg S/F'): 3,
#  ('M26 2SP', 'Fresubin 5kcal Shot_Drink (Neutral)'): 2,
#  ('TS24 7PW', 'Propranolol HCl_Oral Soln 40mg/5ml S/F'): 3,
#  ('WN2 5NG', 'Ramipril_Cap 1.25mg'): 69,
#  ('GL50 4DP', 'Irbesartan_Tab 300mg'): 13,
#  ('DN34 4GB', 'Calogen Extra_Emuls (2 Flav)'): 3,
#  ('S74 9AF', 'Cilest_Tab'): 6,
#  ('DA1 2HA', 'Mefenamic Acid_Cap 250mg'): 4,
#  ('ME8 8AA', 'Simvastatin_Tab 40mg'): 323,
#  ('FY2 0JG', 'Zopiclone_Tab 3.75mg'): 75,
#  ('BB4 5SL', 'Eucerin_Dry Skin Relief Crm + Urea 5%'): 2,
#  ('B23 6DJ', 'Priadel_Tab 200mg'): 7,
#  ('DN22 7XF', 'Movicol_Paed Pdr Sach 6.9g (Choc)'): 5,
#  ('TR1 2JA', 'Naseptin_Crm'): 21,
#  ('TS17 0EE', 'Felodipine_Tab 2.5mg M/R'): 59,
#  ('WN7 2PE', 'Coloplast SpeediCath Compact Fle Size 8-'): 3,
#  ('TN24 0GP', 'Salbutamol_Inha 100mcg (200 D) CFF'): 390,
#  ('CB9 8HF', 'Ciprofloxacin_Gran For Susp 250mg/5ml'): 2,
#  ('CH65 6TG', 'Zapain_Cap 30mg/500mg'): 15,
#  ('M11 4EJ', 'Naseptin_Crm'): 4,
#  ('S63 9EH', 'Lercanidipine HCl_Tab 20mg'): 22,
#  ('CH65 6TG', 'Gedarel_Tab 30/150mcg'): 3,
#  ('RM3 9SU', 'Revaxis_Vac 0.5ml Pfs'): 24,
#  ('NE10 9QG', 'Colecal + Calc Phos_Pdr Sach 800u/3.1g'): 16,
#  ('WF13 1HN', 'Nicotine_Inhalator + Inh Cart 15mg'): 5,
#  ('CH65 6TG', 'Ispag Husk_Gran Eff Sach 3.5g Orange S/F'): 6,
#  ('GL50 4DP', 'Saxagliptin_Tab 5mg'): 111,
#  ('SR5 2LT', 'Vita-POS Paraf Eye Oint P/F'): 5,
#  ('LE10 1DS', 'Aripiprazole_Tab 15mg'): 3,
#  ('CH65 6TG', 'Levothyrox Sod_Tab 50mcg'): 200,
#  ('CW1 3AW', 'Aciclovir_Tab 400mg'): 7,
#  ('TS10 4NW', 'Phyllocontin Continus_Tab 225mg'): 8,
#  ('WN2 5NG', 'Budesonide/Formoterol Inh B/A 400/12(60D'): 18,
#  ('CW1 3AW', 'Nebusal Sod Chlor 7% Inh Soln 4ml'): 2,
#  ('PL7 1AD', 'Clotrimazole_Pess 500mg/Crm 2%'): 35,
#  ('WA10 2DJ', 'Clobet But_Crm 0.05%'): 18,
#  ('DN34 4GB', 'Ursodeoxycholic Acid_Cap 250mg'): 4,
#  ('TS3 6AL', 'OneTouch Ultra (Reagent)_Strips'): 4,
#  ('BB3 1PY', 'Testosterone_Gel 50mg/5g Ud Tube'): 3,
#  ('ST3 6AB', 'Tizanidine HCl_Tab 2mg'): 5,
#  ('SE1 6JP', 'iMEDicare Ultimate (Surefit) Maint Set C'): 2,
#  ('SE15 5LJ', 'Beclomet/Formoterol_Inh 200/6 (120D) CFF'): 2,
#  ('WN7 1HR', 'Sulfasalazine_Tab 500mg'): 6,
#  ('BL9 0SN', 'Lyrica_Cap 200mg'): 14,
#  ('KT6 6EZ', 'Indometacin_Cap 25mg'): 4,
#  ('SE1 6JP', 'Artificial Saliva_Spy 50ml'): 3,
#  ('BL1 8TU', 'Sod Chlor_Inh Soln 0.9% 2.5ml Ud Amp'): 5,
#  ('SK11 6JL', 'Rochester_Clr Advantage Slc Sheath+Aloe'): 3,
#  ('SM6 0HY', 'Glyceryl Trinit_Patch 5mg/24hrs'): 3,
#  ('HU7 4DW', 'Vit B Co_Tab'): 51,
#  ('NE24 1DX', 'Dermol_Crm'): 12,
#  ('HA3 7LT', 'Quinine Sulf_Tab 300mg'): 10,
#  ('BB7 2JG', 'Symbicort_Turbohaler 100mcg/6mcg (120 D)'): 32,
#  ('TS24 7PW', 'Betameth Val_Crm 0.1%'): 53,
#  ('LE5 3GH', 'Hydromol Intensive_Crm 10%'): 2,
#  ('SM6 0HY', 'Warburtons_G/F Bread Wte (Cut)'): 3,
#  ('FY2 0JG', 'Fluoxetine HCl_Oral Soln 20mg/5ml'): 3,
#  ('SK6 1ND', 'Ramipril_Cap 1.25mg'): 83,
#  ('BL3 5HP', 'Clotrimazole_C/Pk Crm 5g 10%/10g 2%'): 2,
#  ('LN2 2JP', 'Coloplast_Elasctd Leg Bag Strap (Washabl'): 5,
#  ('WD18 0JP', 'Bisoprolol Fumar_Tab 1.25mg'): 110,
#  ('B11 4BW', 'Pregabalin_Cap 150mg'): 13,
#  ('ST8 6AG', 'Itraconazole_Cap 100mg'): 2,
#  ('TW13 4GU', 'Carbamazepine_Tab 200mg'): 6,
#  ('TS23 2DG', 'Ondansetron HCl_Tab 4mg'): 6,
#  ('CW5 5NX', 'Nifedipine_Cap 10mg'): 5,
#  ('RM3 9SU', 'Salbutamol_Inha 100mcg (200 D) CFF'): 701,
#  ('LE10 1DS', 'Pravastatin Sod_Tab 40mg'): 40,
#  ('BL9 0NJ', 'Nicorette_QuickMist Oromucosal P/Spy'): 4,
#  ('S74 9AF', 'Doublebase_Gel'): 10,
#  ('SR4 7XF', 'Pentasa SR_Tab 500mg'): 13,
#  ('TR1 2JA', 'Movicol Plain_Paed Pdr Sach 6.9g'): 32,
#  ('SS13 3HQ', 'Marol_Tab 100mg M/R (Teva)'): 4,
#  ('SS9 5UU', 'Prednisolone_Tab 1mg'): 21,
#  ('NE37 2PU', 'Hypromellose/Dextran 70_Eye Dps 0.3/0.1%'): 5,
#  ('WN2 5NG', 'Peppermint Oil_Cap E/C 0.2ml'): 7,
#  ('LE5 3GH', 'Fencino_Transdermal Patch 12mcg/hr'): 3,
#  ('FY5 2TZ', 'Primidone_Tab 250mg'): 3,
#  ('CB9 8HF', 'Butec_Transdermal Patch 5mcg/hr'): 8,
#  ('S63 9EH', 'Metformin HCl_Tab 500mg M/R'): 77,
#  ('LS9 9EF', 'Cinacalcet HCl_Tab 30mg'): 5,
#  ('LN2 2JP', 'Carbamazepine_Tab 200mg'): 19,
#  ('NW10 8RY', 'Oxycodone HCl_Oral Soln 5mg/5ml S/F'): 2,
#  ('TW3 3LN', 'Folic Acid_Tab 5mg'): 209,
#  ('FY4 1TJ', 'Timolol_Eye Dps 0.5%'): 15,
#  ('TW3 3LN', 'Estriol_Crm 0.1% + Applic'): 3,
#  ('KT14 6DH', 'Lansoprazole_Cap 15mg (E/C Gran)'): 282,
#  ('S63 9EH', 'GlucoMen areo Sensor (Reagent)_Strips'): 3,
#  ('L5 0QW', 'Trazodone HCl_Cap 100mg'): 2,
#  ('BH23 3AF', 'Zetuvit E 20cm x 40cm Pfa Cellulose Dres'): 6,
#  ('ST8 6AG', 'Lisinopril_Tab 10mg'): 88,
#  ('W10 6DZ', 'Ferr Fumar_Cap 305mg'): 2,
#  ('WN3 5HL', 'Daktarin_Oromucosal Gel 20mg/g S/F'): 2,
#  ('NE37 2PU', 'Adipine MR 10_Tab 10mg'): 7,
#  ('NE37 2PU', 'Cinnarizine_Tab 15mg'): 26,
#  ('DN34 4GB', 'Naftidrofuryl Oxal_Cap 100mg'): 26,
#  ('BL9 0NJ', 'Gaviscon Advance_Liq (Peppermint) S/F'): 12,
#  ('BD3 8QH', 'Metformin HCl_Tab 850mg'): 128,
#  ('SE15 5LJ', 'Isosorbide Mononit_Tab 60mg M/R'): 6,
#  ('B11 4BW', 'Baclofen_Oral Soln 5mg/5ml S/F'): 5,
#  ('GL1 3PX', 'Proctosedyl_Oint'): 6,
#  ('GL1 3PX', 'Keppra_Tab 1g'): 6,
#  ('TS23 2DG', 'Estradiol_Patch 50mcg/24hrs (AMQ8)'): 2,
#  ('BL9 0NJ', 'Oxytetracycline_Tab 250mg'): 19,
#  ('LN2 2JP', 'Ins NovoRapid_PumpCart 100u/ml 1.6mlCart'): 3,
#  ('TR1 2JA', 'Pholcodine_Linct 5mg/5ml'): 2,
#  ('ST3 6AB', 'Citalopram Hydrob_Tab 20mg'): 397,
#  ('CW5 5NX', 'Longtec_Tab 5mg M/R'): 2,
#  ('TS17 0EE', 'Lacidipine_Tab 4mg'): 7,
#  ('GU9 9QS', 'Ciclesonide_Inh 160mcg (120 D) CFF'): 6,
#  ('S65 1DA', 'Tiotropium_Pdr For Inh Cap 18mcg + Dev'): 50,
#  ('HU7 4DW', 'Travatan_Eye Dps 40mcg/ml'): 2,
#  ('S65 1DA', 'Miconazole_Oromucosal Gel 20mg/g S/F'): 23,
#  ('BB2 1AX', 'Cabergoline_Tab 0.5mg'): 2,
#  ('OL9 7AY', 'Bisoprolol Fumar_Tab 5mg'): 134,
#  ('BL1 8TU', 'Propranolol HCl_Tab 40mg'): 63,
#  ('L31 0DJ', 'Airomir_Autohaler 100mcg (200 D) CFF'): 8,
#  ('NE24 1DX', 'Pregabalin_Cap 300mg'): 53,
#  ('ST3 6AB', 'Venlafaxine_Cap 150mg M/R'): 2,
#  ('BB9 7SR', 'Coloplast_Conveen Optima Urisheath (Non'): 7,
#  ('N9 7HD', 'Digoxin_Tab 62.5mcg'): 22,
#  ('WN3 5HL', 'Adizem-SR_Cap 90mg'): 7,
#  ('SR4 7XF', 'Ramipril_Tab 2.5mg'): 9,
#  ('LS9 9EF', 'Doxazosin Mesil_Tab 1mg'): 23,
#  ('ME8 8AA', 'Toviaz_Tab 4mg M/R'): 2,
#  ('B18 7AL', 'Tamsulosin HCl_Tab 400mcg M/R'): 2,
#  ('W10 6DZ', 'Ramipril_Tab 1.25mg'): 4,
#  ('WN3 5HL', 'Amantadine HCl_Cap 100mg'): 4,
#  ('B11 4BW', 'Oilatum_Gel'): 3,
#  ('LE18 2EW', 'Nedocromil Sod_Eye Dps Aq 2%'): 2,
#  ('DN22 7XF', 'Ipratrop Brom_Inh Soln 500mcg/2ml Ud'): 7,
#  ('ME8 8AA', 'Mometasone Fur_Aq N/Spy 50mcg (140 D)'): 32,
#  ('CB9 8HF', 'Rozex_Gel 0.75%'): 2,
#  ('BB2 1AX', 'Alendronic Acid_Tab 70mg'): 123,
#  ('TS3 6AL', 'Lyrinel XL_Tab 5mg'): 4,
#  ('CV1 4FS', 'Amoxicillin_Cap 250mg'): 23,
#  ('CW7 1AT', 'Viscotears_Liq Gel 2mg/g'): 87,
#  ('NE37 2PU', 'Desogestrel_Tab 75mcg'): 22,
#  ('S74 9AF', 'Liq Paraf Light_Gel 70%'): 6,
#  ('BH23 3AF', 'Activa Leg Ulcer Hose Kit Lge Clsd Toe C'): 3,
#  ('BB9 7SR', 'Co-Codamol Eff_Tab 8mg/500mg'): 18,
#  ('LE18 2EW', 'Lyrica_Cap 25mg'): 5,
#  ('L5 0QW', 'Dalivit_Dps'): 10,
#  ('BL3 5HP', 'Dovobet_Oint 0.005%/0.05%'): 3,
#  ('SR5 2LT', 'Docusate Sod_Oral Soln 50mg/5ml S/F'): 4,
#  ('TS3 6AL', 'Colecal_Cap 400u'): 2,
#  ('TR1 2JA', 'Mycophenolate Mofetil_Tab 500mg'): 10,
#  ('GU9 9QS', 'Evorel 50_Patch'): 16,
#  ('SR5 2LT', 'Nitrofurantoin_Cap 100mg M/R'): 18,
#  ('DN22 7XF', 'Pravastatin Sod_Tab 10mg'): 61,
#  ('BB11 2DL', 'Glucophage SR_Tab 500mg'): 2,
#  ('CW5 5NX', 'Venlafaxine_Tab 75mg'): 18,
#  ('B11 4BW', 'Budesonide_Pdr For Inh 200mcg (100 D)'): 2,
#  ('SK11 6JL', 'Co-Amilofruse_Tab 2.5mg/20mg'): 16,
#  ('NE10 9QG', 'Letrozole_Tab 2.5mg'): 46,
#  ('WS3 3JP', 'Asacol_MR Tab E/C 400mg'): 8,
#  ('SS0 7AF', 'Venaxx XL_Cap 150mg'): 19,
#  ('TN34 1BA', 'Omeprazole_Tab Disper 10mg (E/C Pellets)'): 3,
#  ('CB9 8HF', 'Minocycline HCl_Tab 100mg'): 2,
#  ('FY7 8GU', 'Bisoprolol Fumar_Tab 1.25mg'): 99,
#  ('FY2 0JG', 'Venlafaxine_Tab 37.5mg M/R'): 3,
#  ('NN16 8DN', 'Irbesartan_Tab 300mg'): 8,
#  ('TW8 8DS', 'Ivabradine_Tab 5mg'): 17,
#  ('TS17 0EE', 'Terbut Sulf_B/A Inha 500mcg (100 D)'): 73,
#  ('S63 9EH', 'Methylphenidate HCl_Tab 20mg'): 3,
#  ('N9 7HD', 'Ster Dress Pack'): 3,
#  ('B18 7AL', 'Fostair_Inh 200mcg/6mcg (120D) CFF'): 9,
#  ('B70 7AW', 'Chloramphen_Eye Oint 1%'): 22,
#  ('L7 6HD', 'BD Micro-Fine + Lancets 0.20mm/33 Gauge'): 2,
#  ('KT6 6EZ', 'Sulfasalazine_Tab E/C 500mg'): 25,
#  ('CT11 8AD', 'Ipratrop Brom_Inha 20mcg (200 D) CFF'): 23,
#  ('BL9 0SN', 'Levothyrox Sod_Tab 25mcg'): 273,
#  ('NG7 5HY', 'Seretide 125_Evohaler 125mcg/25mcg(120D)'): 10,
#  ('L5 0QW', 'Carbamazepine_Tab 200mg'): 11,
#  ('TS10 4NW', 'Sando-K_Tab Eff 470mg'): 5,
#  ('NW10 8RY', 'Nurse It Ster Dress Pack'): 7,
#  ('NE24 1DX', 'Pregabalin_Cap 50mg'): 13,
#  ('OL4 1YN', 'Fusidic Acid_Crm 2%'): 42,
#  ('WS10 8SY', 'Dermol 600_Bath Emollient'): 6,
#  ('M35 0AD', 'Isosorbide Mononit_Tab 50mg M/R'): 4,
#  ('BB4 5SL', 'Warfarin Sod_Tab 1mg'): 110,
#  ('LS9 9EF', 'Nasonex_Aq N/Spy 50mcg (140 D)'): 11,
#  ('WN2 5NG', 'Citalopram Hydrob_Tab 10mg'): 116,
#  ('SS9 5UU', 'Aquacel Ribbon 1cm x 45cm Wound Dress Ca'): 3,
#  ('SS0 7AF', 'Spiriva_Pdr For Inh Cap 18mcg+HandiHaler'): 4,
#  ('BH18 8EE', 'Mometasone Fur_Scalp Lot 0.1%'): 2,
#  ('ST3 6AB', 'Aspirin_Tab E/C 75mg'): 272,
#  ('SS0 7AF', 'Nitrazepam_Tab 5mg'): 27,
#  ('BB9 7SR', 'Complan_Shake Pdr Sach 57g (Banana)'): 4,
#  ('TW3 3LN', 'Premarin_Tab 625mcg'): 2,
#  ('CB9 8HF', 'Esomeprazole_Cap E/C 40mg'): 11,
#  ('L36 7XY', 'Rivaroxaban_Tab 15mg'): 5,
#  ('HA3 7LT', 'Non-Woven Fabric Swab 10cm x 10cm Non-St'): 2,
#  ('SK11 6JL', 'L.IN.C All Slc Stnd+Water 16-24 10ml Uni'): 4,
#  ('S65 1DA', 'Donepezil HCl_Orodisper Tab 10mg S/F'): 4,
#  ('RM3 9SU', '3m Health Care_Cavilon No Sting 3ml Barr'): 2,
#  ('CT11 8AD', 'Fluticasone Prop_Susp Nsl Dps 400mcg Ud'): 8,
#  ('M35 0AD', 'Lactic Acid/Salic Acid_Paint 16.7/16.7%'): 2,
#  ('DN22 7XF', 'Voltarol Emulgel_Aq Gel 1.16%'): 26,
#  ('CT11 8AD', 'Simvastatin_Tab 40mg'): 528,
#  ('SS0 7AF', 'Domperidone_Susp 5mg/5ml S/F'): 2,
#  ('CW5 5NX', 'Fluvastatin Sod_Cap 20mg'): 7,
#  ('L5 0QW', 'Budesonide/Formoterol Inh B/A 100/6(120D'): 3,
#  ('ST8 6AG', 'M.Sauer_NephSys Ster Drain Bag 500ml 20c'): 2,
#  ('M30 0NU', 'Nystatin_Oral Susp 100 000u/ml'): 9,
#  ('BB2 1AX', 'Ondansetron HCl_Tab 8mg'): 3,
#  ('WA10 2DJ', 'Thiamine HCl_Tab 50mg'): 25,
#  ('L7 6HD', 'Clarithromycin_Tab 500mg'): 69,
#  ('N9 7HD', 'Labetalol HCl_Tab 200mg'): 4,
#  ('TR1 2JA', 'Co-Codamol_Tab 8mg/500mg'): 128,
#  ('NE37 2PU', 'OneTouch Ultra (Reagent)_Strips'): 5,
#  ('HU7 4DW', 'Toviaz_Tab 8mg M/R'): 2,
#  ('WA9 1LN', 'Ibuprofen_Tab 200mg'): 8,
#  ('L7 6HD', 'Gaviscon Infant_Sach 2g (Dual Pack) S/F'): 17,
#  ('BD3 8QH', 'Contour (Reagent)_Strips'): 5,
#  ('WS3 3JP', 'Indacaterol Mal_Pdr Inh Cap 150mcg + Dev'): 4,
#  ('B23 6DJ', 'Vit B Co_Tab'): 7,
#  ('LE10 1DS', 'Ipratrop Brom_Aq Nsl Spy 21mcg (180D)CFF'): 2,
#  ('SR5 2LT', 'Epaderm Oint'): 11,
#  ('BL1 8TU', 'Elocon_Crm 0.1%'): 7,
#  ('NE38 7NQ', 'Calamine_Lot'): 2,
#  ('LN2 2JP', 'Hydralazine HCl_Tab 50mg'): 4,
#  ('ST3 6AB', 'Paracet_Tab 500mg'): 761,
#  ('GU9 9QS', 'Buprenorphine_Patch 70mcg/hr (96hr)'): 2,
#  ('FY5 2TZ', 'Aquamax Crm (Appl)'): 19,
#  ('NE10 9QG', 'Microlet Lancets 0.5mm/28 Gauge'): 7,
#  ('S63 9EH', 'Sytron_Elix 190mg/5ml S/F'): 3,
#  ('WS10 8SY', 'Salbutamol_Inh Soln 5mg/2.5ml Ud'): 3,
#  ('HA3 7LT', 'Sukkarto SR_Tab 1000mg'): 86,
#  ('NE10 9QG', 'Morph Sulf_Oral Soln 10mg/5ml'): 151,
#  ('HG1 5AR', 'Bendroflumethiazide_Tab 5mg'): 5,
#  ('BB9 7SR', 'Memantine HCl_Tab 20mg'): 6,
#  ('WV13 2DR', 'Mezavant XL_Tab G/R 1.2g'): 2,
#  ('ST3 6AB', 'Salbutamol_Inha 100mcg (200 D) CFF'): 800,
#  ('BL9 0NJ', 'Mefenamic Acid_Tab 500mg'): 12,
#  ('WA9 1LN', 'Atenolol_Tab 100mg'): 32,
#  ('NN16 8DN', 'Duloxetine HCl_Cap G/R 60mg'): 87,
#  ('NG7 3GW', 'Colecal_Tab 800u'): 13,
#  ('CV1 4FS', 'Glyceryl Trinit_Sub P/Spy 400mcg (200D)'): 3,
#  ('OL1 1NL', 'Morph Sulf_Cap 10mg M/R'): 6,
#  ('TS1 2NX', 'Tramadol HCl_Tab 50mg M/R'): 3,
#  ('TW8 8DS', 'Co-Codamol Eff_Tab 8mg/500mg'): 4,
#  ('OL11 1DN', 'Dianette_Tab 2mg/35mcg'): 4,
#  ('HA3 7LT', 'Fenbid_Gel 5%'): 201,
#  ('WS10 8SY', 'Naproxen_Tab E/C 250mg'): 31,
#  ('GL50 4DP', 'Codeine Phos_Tab 60mg'): 8,
#  ('BL9 0NJ', 'Bimatoprost/Timolol_Eye Dps 300mcg/5mg'): 8,
#  ('S65 1DA', 'Biotene Moisturising Mthwsh'): 3,
#  ('HA3 7LT', 'Lodoxamide Trometamol_Eye Dps 0.1%'): 3,
#  ('TS17 0EE', 'Dermol_Crm'): 27,
#  ('B23 6DJ', 'Propranolol HCl_Tab 40mg'): 49,
#  ('GU9 9QS', 'Monomax XL_Tab 60mg'): 17,
#  ('ST3 6AB', 'Nicotine_Transdermal Patch 21mg/24hrs'): 3,
#  ('CW7 1AT', 'Vensir XL_Cap 75mg'): 49,
#  ('CB9 8HF', 'Diclofenac Sod_Cap E/C 25mg/50mg M/R'): 7,
#  ('S63 9EH', 'Dexameth_Tab 2mg'): 2,
#  ('BL9 0SN', 'Rigevidon_Tab'): 68,
#  ('WN2 5NG', 'Amoxicillin_Cap 250mg'): 3,
#  ('FY4 1TJ', 'Calcichew_Tab Chble 1.25g (500mg)'): 7,
#  ('DN34 4GB', 'NovoFine Needles Pen Inj Screw On 6mm'): 3,
#  ('WN3 5HL', 'Paracet_Tab 500mg'): 616,
#  ('NE24 1DX', 'Dorzolamide_Eye Dps 2%'): 25,
#  ('GU9 9QS', 'Ethinylest/Desogestrel_Tab 30mcg/150mcg'): 4,
#  ('SM3 8EP', 'Epaderm Oint'): 7,
#  ('PL7 1AD', 'OneTouch Verio (Reagent)_Strips'): 5,
#  ('TW8 8DS', 'Co-Codamol Eff_Tab 30mg/500mg'): 13,
#  ('FY7 8GU', 'Liq Paraf/Isopropyl Myrist_Gel 15%/15%'): 2,
#  ('WN7 1HR', 'Sildenafil_Tab 50mg'): 28,
#  ('L5 0QW', 'Ins NovoMix 30_FlexPen 100u/ml 3ml PfPen'): 24,
#  ('GU9 9QS', 'Peristeen Accessory Unit'): 6,
#  ('S65 1DA', 'Calcipotriol/Betameth_Oint 0.005%/0.05%'): 24,
#  ('CH1 4DS', 'Calcipotriol/Betameth_Oint 0.005%/0.05%'): 9,
#  ('NE37 2PU', 'Zolpidem Tart_Tab 5mg'): 16,
#  ('DN34 4GB', 'Fluticasone Prop_Inha 125mcg (120 D) CFF'): 7,
#  ('B70 7AW', 'Fenofibrate_Tab 160mg (Micronised)'): 20,
#  ('SS13 3HQ', 'Nitrolingual_P/Spy 400mcg (180 D)'): 4,
#  ('CW5 5NX', 'Diazepam_Tab 5mg'): 77,
#  ('L31 0DJ', 'Ins NovoMix 30_Penfill 100u/ml 3ml Cart'): 3,
#  ('LE5 3GH', 'Hux D3_Cap 20 000u'): 8,
#  ('OL11 1DN', 'Codeine Phos_Tab 15mg'): 7,
#  ('NN16 8DN', 'Doublebase_Gel'): 49,
#  ('CW5 5NX', 'Movelat_Gel'): 12,
#  ('GU9 9QS', 'White Soft Paraf/Liq Paraf_(S) 50%/50%'): 4,
#  ('GL50 4DP', 'Sod Valpr_Oral Soln 200mg/5ml S/F'): 4,
#  ('TS24 7PW', 'Calcipotriol_Oint 50mcg/1g'): 13,
#  ('BB4 5SL', 'Hyoscine Hydrob_Inj 400mcg/ml 1ml Amp'): 12,
#  ('L7 6HD', 'Easyhaler_Salbutamol Sulf 100mcg (200D)'): 10,
#  ('ST1 4PB', 'Paracet_Tab Solb 500mg'): 13,
#  ('WS10 8SY', 'Carvedilol_Tab 6.25mg'): 2,
#  ('ME8 8AA', 'Typhim VI_Vac 0.5ml Pfs'): 25,
#  ('WN2 5NG', 'Aminophylline Hydrate_Tab 225mg M/R'): 2,
#  ('BL3 5HP', 'Levothyrox Sod_Tab 50mcg'): 195,
#  ('WN7 1HR', 'Warfarin Sod_Tab 3mg'): 116,
#  ('OL11 1DN', 'Colecal & Calc_Tab Chble 400u/1.5g'): 8,
#  ('BB8 0JZ', 'Elantan LA 25_Cap 25mg'): 24,
#  ('LA1 1PN', 'Naproxen_Tab 500mg'): 276,
#  ('YO16 4LZ', 'Aspirin_Tab 75mg'): 33,
#  ('LE10 1DS', 'Ropinirole HCl_Tab 2mg'): 4,
#  ('LE18 2EW', 'Varenicline Tart_Tab 1mg'): 4,
#  ('CW1 3AW', 'GlucoMen areo Sensor (Reagent)_Strips'): 15,
#  ('CH1 4DS', 'Scopoderm_Patch 1mg/72hrs'): 2,
#  ('GL50 4DP', 'Eumovate_Oint 0.05%'): 19,
#  ('WF13 1HN', 'Hypromellose_Eye Dps 0.5%'): 4,
#  ('CB9 8HF', 'GlucoRx Nexus (Reagent)_Strips'): 7,
#  ('ST3 6AB', 'Diltiazem HCl_Cap 90mg M/R'): 11,
#  ('N9 7HD', 'Lisinopril_Tab 5mg'): 70,
#  ('BB4 5SL', 'Naproxen_Tab E/C 500mg'): 3,
#  ('SS13 3HQ', 'Ropinirole HCl_Tab 2mg'): 6,
#  ('PL7 1AD', 'Methyldopa_Tab 125mg'): 2,
#  ('BB11 2DL', 'Xailin HA Sod Hyaluronate 0.2% Eye Dps 1'): 3,
#  ('BB2 1AX', 'Amoxicillin_Oral Susp 125mg/5ml S/F'): 29,
#  ('BB11 2DL', 'Paroxetine HCl_Tab 20mg'): 34,
#  ('LE10 1DS', 'Clobet But_Crm 0.05%'): 19,
#  ('RM3 9SU', 'iMEDicare Ultimate (Surefit) Maint Set C'): 2,
#  ('CH1 4DS', 'Xailin Night Paraf Eye Oint P/F 5g'): 4,
#  ('S65 1DA', 'Salicylic Acid/Mucopolysac_Gel 2%/0.2%'): 11,
#  ('WV13 2DR', 'Clarithromycin_Oral Susp 250mg/5ml'): 3,
#  ('TS24 7PW', 'Pivmecillinam HCl_Tab 200mg'): 16,
#  ('HG1 5AR', 'Class 1 Stnd C/Kt Thigh Stkn Elas Hose'): 2,
#  ('KT6 6EZ', 'Amoxicillin_Cap 250mg'): 9,
#  ('OL1 1NL', 'Bezafibrate_Tab 200mg'): 4,
#  ('TW13 4GU', 'Chlorpromazine HCl_Tab 50mg'): 2,
#  ('OL4 1YN', 'Buscopan_Tab 10mg'): 8,
#  ('WS10 8SY', 'Alfacalcidol_Cap 1mcg'): 3,
#  ('WA7 1AB', 'Co-Careldopa_Tab 50mg/200mg M/R'): 4,
#  ('S65 1DA', 'Hydrocort_Crm 0.5%'): 5,
#  ('TW13 4GU', 'Movicol_Pdr Sach 13.8g (Lem & Lim)'): 3,
#  ('SR4 7XF', 'Colesevelam HCl_Tab 625mg'): 3,
#  ('SK11 6JL', 'Relvar Ellipta_Inha 92mcg/22mcg (30 D)'): 81,
#  ('SR4 7XF', 'Omeprazole_Tab Disper 20mg (E/C Pellets)'): 2,
#  ('WA9 1LN', 'Quetiapine_Tab 100mg'): 29,
#  ('LN2 2JP', 'Coloplast_Simpla Profile Night Bag + 120'): 13,
#  ('TS10 4NW', 'Adizem-XL_Cap 240mg'): 21,
#  ('DN22 7XF', 'Bisoprolol Fumar_Tab 3.75mg'): 32,
#  ('OL9 7AY', 'Bisacodyl_Tab E/C 5mg'): 12,
#  ('OL9 7AY', 'Lodoxamide Trometamol_Eye Dps 0.1%'): 3,
#  ('FY4 1TJ', 'Ins Glargine_Inj 100u/ml 3ml Pf Pen'): 15,
#  ('ST1 4PB', 'Tiotropium_Pdr For Inh Cap 18mcg + Dev'): 30,
#  ('B18 7AL', 'GlucoRX FinePoint Needles Pen Inj Screw'): 17,
#  ('WA10 2DJ', 'Promethazine HCl_Tab 25mg'): 4,
#  ('ST8 6AG', 'Diclofenac Sod_Gel 1.16%'): 115,
#  ('S74 9AF', 'Peptac_Liq (Peppermint) S/F'): 54,
#  ('TW13 4GU', 'Scheriproct_Oint'): 3,
#  ('DA1 2HA', 'Rigevidon_Tab'): 31,
#  ('NE38 7NQ', 'Difflam_P/Spy 0.15% 30ml'): 7,
#  ('SM6 0HY', 'Venlafaxine_Tab 37.5mg M/R'): 5,
#  ('BL1 8TU', 'Lactic Acid/Salic Acid_Paint 16.7/16.7%'): 2,
#  ('GL50 4DP', 'Amiloride HCl_Tab 5mg'): 11,
#  ('WV13 2DR', 'Quinine Bisulf_Tab 300mg'): 3,
#  ('FY5 2TZ', 'Levonorgest_Tab 1.5mg'): 5,
#  ('CH65 6TG', 'Solpadol_Capl 30mg/500mg'): 4,
#  ('ST8 6AG', 'Glyceryl Trinit_Sub P/Spy 400mcg (180D)'): 68,
#  ('FY2 0JG', 'Adipine MR 10_Tab 10mg'): 4,
#  ('FY2 0JG', 'Cinnarizine_Tab 15mg'): 26,
#  ('WD18 0JP', 'Fesoterodine Fumar_Tab 4mg M/R'): 18,
#  ('BH18 8EE', 'Dansac_Nova Mini Cap Opqe C/Fit 20-50mm'): 3,
#  ('BH23 3AF', 'Coloplast_S5 Urine Drain Bag 2L'): 2,
#  ('KT6 6EZ', 'Hydrous_Oint'): 11,
#  ('KT6 6EZ', 'Perindopril Erbumine_Tab 4mg'): 28,
#  ('SK6 1ND', 'Aspirin Disper_Tab 300mg'): 7,
#  ('HA0 4UZ', 'Metformin HCl_Tab 1g M/R'): 48,
#  ('BB4 5SL', 'Ins NovoMix 30_Penfill 100u/ml 3ml Cart'): 8,
#  ('M35 0AD', 'Aciclovir_Tab 400mg'): 11,
#  ('NG7 3GW', 'Sumatriptan_Tab 50mg'): 19,
#  ('WA7 1AB', 'Hydroxycarbamide_Cap 500mg'): 9,
#  ('LE10 1DS', 'Losartan Pot_Tab 50mg'): 271,
#  ('W10 6DZ', 'Codeine Phos_Tab 30mg'): 39,
#  ('TS3 6AL', 'Hylo-Tear Sod Hyaluronate Eye Dps 0.1% P'): 2,
#  ('B23 6DJ', 'Tamsulosin HCl_Tab 400mcg M/R'): 3,
#  ('WS10 8SY', 'Salazopyrin-En_Tab 500mg'): 2,
#  ('CH1 4DS', 'Celiprolol HCl_Tab 200mg'): 2,
#  ('BL1 8TU', 'Celluvisc_Eye Dps 1% 0.4ml Ud'): 9,
#  ('ST1 4PB', 'Ensure Compact_Liq (4 Flav)'): 19,
#  ('B21 9RY', 'Doublebase_Gel'): 47,
#  ('SS0 7AF', 'Migraleve_Pink Tab'): 4,
#  ('SS8 0JA', 'Lisinopril/Hydchloroth_Tab 10mg/12.5mg'): 4,
#  ('N9 7HD', 'Dalacin T_Top Lot 1%'): 2,
#  ('SK11 6JL', 'Cyclopentolate HCl_Eye Dps 1%'): 3,
#  ('CW5 5NX', 'Testogel_Gel Sach 50mg/5g'): 2,
#  ('OL4 1YN', 'Salamol E-Breathe_Inh 100mcg (200 D) CFF'): 12,
#  ('OL4 1YN', 'Anoro Ellipta_Inha 55mcg/22mcg (30D)'): 11,
#  ('TN24 0GP', 'Nicorette_QuickMist Oromucosal P/Spy'): 3,
#  ('TS24 7PW', "Glycerol_Suppos Adult's (4g)"): 10,
#  ('B23 6DJ', 'Bicalutamide_Tab 50mg'): 4,
#  ('L7 6HD', 'Pioglitazone/Metformin HCl_Tab15mg/850mg'): 5,
#  ('SS0 7AF', 'Oilatum Jnr_Crm (Liq)'): 3,
#  ('SE15 5LJ', 'Betahistine HCl_Tab 16mg'): 19,
#  ('SR4 7XF', 'Salbutamol_Inh Soln 2.5mg/2.5ml Ud'): 28,
#  ('BB8 0JZ', 'Ropinirole HCl_Tab 2mg'): 5,
#  ('LN2 2JP', 'Ramipril_Tab 5mg'): 24,
#  ('SS9 5UU', 'Colofac_Tab 135mg'): 9,
#  ('L36 7XY', 'Anoro Ellipta_Inha 55mcg/22mcg (30D)'): 4,
#  ('WD18 0JP', 'Promethazine HCl_Tab 25mg'): 15,
#  ('GL50 4DP', 'Estradiol_Tab 2mg'): 5,
#  ('FY7 8GU', 'Aciclovir_Tab 200mg'): 7,
#  ('BB11 2DL', 'Sod Valpr_Tab 500mg M/R'): 4,
#  ('WV13 2DR', 'Buprenorphine_Tab Subling 400mcg S/F'): 8,
#  ('SK11 6JL', 'Co-Careldopa_Tab 50mg/200mg M/R'): 2,
#  ('LE5 3GH', 'Choline Sal_Dental Gel 8.7% S/F'): 3,
#  ('ST1 4PB', 'Topiramate_Tab 25mg'): 6,
#  ('DN34 4GB', 'Saline Steripoule_Inh Soln 0.9% 2.5ml Ud'): 3,
#  ('WN2 5NG', 'Pholcodine_Linct 5mg/5ml'): 12,
#  ('WA7 1AB', 'Relvar Ellipta_Inha 92mcg/22mcg (30 D)'): 7,
#  ('NE24 1DX', 'Chlorhex Glucon_Mthwsh 0.2%'): 13,
#  ('OL9 7AY', 'Betameth Val/Fusidic Acid_Crm 0.1%/2%'): 12,
#  ('SK6 1ND', 'Trimethoprim_Oral Susp 50mg/5ml S/F'): 6,
#  ('BB11 2DL', 'Verapamil HCl_Tab 240mg M/R'): 7,
#  ('S63 9EH', 'Trandolapril_Cap 2mg'): 6,
#  ('ST8 6AG', 'Lustral_Tab 50mg'): 3,
#  ('CT11 8AD', 'Tildiem_Tab 60mg'): 9,
#  ('GL50 4DP', 'Pregabalin_Cap 100mg'): 9,
#  ('BB8 0JZ', 'Sotalol HCl_Tab 80mg'): 6,
#  ('S65 1DA', 'Aciclovir_Tab 200mg'): 5,
#  ('WA7 1AB', 'Thiamine HCl_Tab 50mg'): 30,
#  ('GL50 4DP', 'Ciclosporin_Eye Dps 0.1% 0.3ml Ud'): 2,
#  ('WN7 1HR', 'Aciclovir_Tab 800mg'): 9,
#  ('W10 6DZ', 'Anusol_Crm'): 7,
#  ('KT14 6DH', 'Hydro-Caine Syrg Lubricant Gel 11ml'): 2,
#  ('ME8 8AA', 'Betnovate_Oint 0.1%'): 2,
#  ('SR4 7XF', 'Donepezil HCl_Tab 10mg'): 146,
#  ('LS9 9EF', 'Quinapril HCl_Tab 40mg'): 3,
#  ('S74 9AF', 'Budesonide_Pdr For Inh 400mcg (50 D)'): 5,
#  ('WA10 2DJ', 'Noriday_Tab 350mcg'): 5,
#  ('WN2 5NG', 'Sulfasalazine_Tab E/C 500mg'): 21,
#  ('WA10 2DJ', 'Salamol_Inha 100mcg (200 D) CFF (Teva)'): 8,
#  ('B21 9RY', 'Ferr Fumar_Tab 322mg'): 22,
#  ('LE10 1DS', "Glycerol_Suppos Adult's (4g)"): 8,
#  ('TS1 2NX', 'Propranolol HCl_Tab 10mg'): 60,
#  ('HA0 4UZ', 'Salic Acid/Lactic Acid_Gel 11%/4%'): 3,
#  ('WD18 0JP', 'Isosorbide Mononit_Tab 60mg M/R'): 2,
#  ('PL7 1AD', 'Oilatum_Shower Gel Fragrance Free'): 14,
#  ('BL9 0SN', 'Betmiga_Tab 50mg M/R'): 9,
#  ('M30 0NU', 'Priadel_Tab 200mg'): 13,
#  ('TS1 2NX', 'Diclofenac Sod_Gel 2.32%'): 65,
#  ('S65 1DA', 'Adalat Ret_Tab 10mg'): 4,
#  ('HA3 7LT', 'InVita D3_Oral Soln 25 000u/1ml'): 62,
#  ('BH18 8EE', 'Hydroxyzine HCl_Tab 10mg'): 10,
#  ('W10 6DZ', 'Hyoscine Hydrob_Tab 300mcg'): 3,
#  ('W10 6DZ', 'Erythromycin_Ethylsuc Susp 125mg/5ml S/F'): 3,
#  ('CT11 8AD', 'Simvastatin_Tab 80mg'): 13,
#  ('HA0 4UZ', 'Zerocream (Appl)'): 7,
#  ('L7 6HD', 'Buprenorphine_Tab Subling 2mg S/F'): 4,
#  ('NE38 7NQ', 'Sod Algin/Pot Bicarb_Susp S/F'): 9,
#  ('NE10 9QG', 'Omeprazole_Cap E/C 40mg'): 17,
#  ('SR5 2LT', 'Amitriptyline HCl_Tab 25mg'): 119,
#  ('S65 1DA', 'Ranolazine_Tab 500mg M/R'): 5,
#  ('SS8 0JA', 'Co-Amilozide_Tab 5mg/50mg'): 8,
#  ('WA10 2DJ', 'Gabapentin_Tab 800mg'): 2,
#  ('WA10 2DJ', 'Mefenamic Acid_Cap 250mg'): 3,
#  ('ST3 6AB', 'Pelican_Cohesive Slims Sml 48mm'): 3,
#  ('SR5 2LT', 'Tiotropium_Pdr For Inh Cap 18mcg + Dev'): 25,
#  ('TS17 0EE', 'Co-Codamol_Tab 30mg/500mg'): 327,
#  ('HG1 5AR', 'K-Plus 10cm x 8.7m M/Layer Compress Band'): 2,
#  ('NW10 8RY', 'Pizotifen Malate_Tab 500mcg'): 4,
#  ('BH18 8EE', 'AquaForm H/Gel 8g Wound Dress Ster'): 4,
#  ('SR4 7XF', 'E45_Crm'): 63,
#  ('HA0 4UZ', 'Seretide 250_Evohaler 250mcg/25mcg(120D)'): 11,
#  ('TS3 6AL', 'Bisoprolol Fumar_Tab 3.75mg'): 26,
#  ('CW7 1AT', 'Modafinil_Tab 100mg'): 2,
#  ('WN7 1HR', 'Colecal & Calc_Tab Chble 400u/1.5g'): 23,
#  ('M35 0AD', 'Sudocrem_Antis Healing Crm'): 8,
#  ('S74 9AF', 'Hyoscine Butylbrom_Inj 20mg/ml 1ml Amp'): 7,
#  ('TW13 4GU', 'Cinchocaine HCl/Hydrocort_Suppos 5mg/5mg'): 2,
#  ('CH1 4DS', 'Inadine 5cm x 5cm Povidone Iodine Fabric'): 13,
#  ('FY4 1TJ', 'Trospium Chlor_Tab 20mg'): 7,
#  ('LA1 1PN', 'Peppermint Oil_Cap E/C 0.2ml'): 11,
#  ('WA10 2DJ', 'Alendronic Acid_Tab 70mg'): 266,
#  ('B70 7AW', 'Codeine Phos_Linct 15mg/5ml S/F'): 28,
#  ('SS0 7AF', 'Coloplast SpeediCath Compact Plus Fle 10'): 2,
#  ('LE10 1DS', 'OneTouch Ultra (Reagent)_Strips'): 7,
#  ('M26 2SP', 'Brimonidine Tart_Eye Dps 0.2%'): 8,
#  ('LE10 1DS', 'Gabapentin_Cap 300mg'): 174,
#  ('LS9 9EF', 'Bezafibrate_Tab 400mg M/R'): 6,
#  ('OL9 7AY', 'Co-Amoxiclav_Tab 250mg/125mg'): 9,
#  ('SM6 0HY', 'Diazepam_Tab 5mg'): 71,
#  ('BB7 2JG', 'Co-Beneldopa_Cap 12.5mg/50mg'): 15,
#  ('B18 7AL', 'Duloxetine HCl_Cap G/R 60mg'): 30,
#  ('BL9 0NJ', 'Kliovance_Tab'): 4,
#  ('LS9 9EF', 'Sotalol HCl_Tab 80mg'): 5,
#  ('SS9 5UU', 'Sumatriptan_Tab 100mg'): 5,
#  ('WD18 0JP', 'Olanzapine_Tab 2.5mg'): 10,
#  ('NE37 2PU', 'Glyceryl Trinit_Sub P/Spy 400mcg (180D)'): 62,
#  ('TS10 4NW', 'Verapamil HCl_Tab 120mg'): 6,
#  ('TS3 6AL', 'H & R_Proshield Foam & Spy Skin Cleanser'): 8,
#  ('WN2 5NG', 'OneTouch Select Plus (Reagent)_Strips'): 4,
#  ('FY5 2TZ', 'Benzydamine HCl_Mthwsh 0.15% S/F'): 5,
#  ('LS9 9EF', 'Aviva (Reagent)_Strips'): 38,
#  ('ST8 6AG', 'Sildenafil_Tab 50mg'): 54,
#  ('BL9 0NJ', 'Carbocisteine_Cap 375mg'): 58,
#  ('ST1 4PB', 'Fluclox Sod_Cap 250mg'): 6,
#  ('LE18 2EW', 'Isomol Gel 500g'): 20,
#  ('HG1 5AR', 'Oxybutynin HCl_Tab 2.5mg'): 15,
#  ('FY5 2TZ', 'Meloxicam_Tab 15mg'): 5,
#  ('YO16 4LZ', 'Tamsulosin HCl_Cap 400mcg M/R'): 448,
#  ('S63 9EH', 'Mometasone Fur_Crm 0.1%'): 8,
#  ('LS9 9EF', 'Olanzapine_Tab 5mg'): 32,
#  ('OL4 1YN', 'Tamsulosin HCl_Cap 400mcg M/R'): 102,
#  ('TR1 2JA', 'Amiloride HCl_Tab 5mg'): 8,
#  ('CT11 8AD', 'Nystatin_Oral Susp 100 000u/ml'): 3,
#  ('LN2 2JP', 'Trulicity_Inj 1.5mg/0.5ml Pf Pen'): 10,
#  ('HG1 5AR', 'Propranolol HCl_Cap 160mg M/R'): 12,
#  ('YO16 4LZ', 'Zapain_Tab 30mg/500mg'): 225,
#  ('CB9 8HF', 'Co-Codamol_Tab 15mg/500mg'): 55,
#  ('BB8 0JZ', 'Fluticasone/Salmeterol_Inh 500/50mcg 60D'): 22,
#  ('B23 6DJ', 'Oilatum Jnr_Bath Additive'): 36,
#  ('KT6 6EZ', 'Peppermint Oil_Cap E/C 0.2ml'): 17,
#  ('HG1 5AR', 'Methotrexate_Tab 2.5mg'): 65,
#  ('DN34 4GB', 'Tolterodine_Tab 1mg'): 6,
#  ('SK6 1ND', 'Irbesartan/Hydchloroth_Tab 150mg/12.5mg'): 2,
#  ('GL50 4DP', 'Peristeen Accessory Unit'): 6,
#  ('FY7 8GU', 'Seretide 50_Evohaler 50mcg/25mcg (120 D)'): 10,
#  ('WN3 5HL', 'Miconazole_Oromucosal Gel 20mg/g S/F'): 7,
#  ('TS3 6AL', 'Timolol_Eye Dps 0.5%'): 5,
#  ('CT11 8AD', 'Tylex_Cap 30mg/500mg'): 2,
#  ('NG7 5HY', 'Emollin Emollient Aero 240ml'): 4,
#  ('TS3 6AL', 'Loperamide HCl_Oral Soln 1mg/5ml S/F'): 3,
#  ('GL50 4DP', 'Levothyrox Sod_Tab 50mcg'): 736,
#  ('BH23 3AF', 'Ranolazine_Tab 375mg M/R'): 2,
#  ('KT6 6EZ', 'Omeprazole_Cap E/C 20mg'): 1152,
#  ('BH18 8EE', 'Sumatriptan_Tab 50mg'): 62,
#  ('YO16 4LZ', 'Buprenorphine_Tab Subling 400mcg S/F'): 6,
#  ('SM3 8EP', 'Chloramphen_Eye Dps 0.5%'): 42,
#  ('CH1 4DS', 'Rigevidon_Tab'): 11,
#  ('ME8 8AA', 'Co-Careldopa_Tab 12.5mg/50mg'): 2,
#  ('FY5 2TZ', 'Fusidic Acid_Crm 2%'): 69,
#  ('DN22 7XF', 'Carmellose Sod_Eye Dps 1% 0.4ml Ud P/F'): 17,
#  ('B21 9RY', 'Pantoprazole_Tab E/C 40mg'): 15,
#  ('L31 0DJ', 'Mefenamic Acid_Tab 500mg'): 4,
#  ('SE15 5LJ', 'Fexofenadine HCl_Tab 180mg'): 16,
#  ('SK11 6JL', 'Depo-Medrone_Inj 40mg/1ml Vl'): 14,
#  ('GL1 3PX', 'Fluoxetine HCl_Cap 20mg'): 245,
#  ('BB8 0JZ', 'Letrozole_Tab 2.5mg'): 39,
#  ('BH23 3AF', 'Bendroflumethiazide_Tab 5mg'): 6,
#  ('M11 4EJ', 'Dapagliflozin_Tab 5mg'): 6,
#  ('BB3 1PY', 'ReQuip XL_Tab 4mg'): 4,
#  ('FY2 0JG', 'Domperidone_Tab 10mg'): 48,
#  ('OL9 7AY', 'Ciprofloxacin_Eye Dps 0.3%'): 2,
#  ('OL1 1NL', 'Buprenorphine_Patch 70mcg/hr (96hr)'): 5,
#  ('BB4 5SL', 'Blephaclean_Eye Lid Wipe'): 9,
#  ('OL9 7AY', 'Pravastatin Sod_Tab 20mg'): 14,
#  ('N9 7HD', 'Valsartan_Cap 40mg'): 12,
#  ('WD18 0JP', 'Nortriptyline_Tab 10mg'): 14,
#  ('N9 7HD', 'Testosterone_Gel 50mg/5g Ud Sach'): 2,
#  ('DA1 2HA', 'Sitagliptin_Tab 50mg'): 17,
#  ('L31 0DJ', 'Bimatoprost/Timolol_Eye Dps 300mcg/5mg'): 12,
#  ('B11 4BW', 'Clotrimazole_Crm 1%'): 41,
#  ('B70 7AW', 'Fexofenadine HCl_Tab 120mg'): 20,
#  ('LA1 1PN', 'Spiriva_Pdr For Inh Cap 18mcg'): 5,
#  ('NE38 7NQ', 'Metoprolol Tart_Tab 100mg'): 10,
#  ('SS0 7AF', 'Methotrexate_Tab 2.5mg'): 46,
#  ('NG7 5HY', 'Cyclizine HCl_Tab 50mg'): 22,
#  ('GL50 4DP', 'Ins Apidra_100u/ml 3ml Cart'): 4,
#  ('DA11 8BZ', 'Piriton_Syr 2mg/5ml'): 8,
#  ('WA10 2DJ', 'Glucoject PLUS Lancets 0.20mm/33 Gauge'): 3,
#  ('BH23 3AF', 'Laxido_Oral Pdr Sach (Orange) S/F'): 9,
#  ('L7 6HD', 'Prochlpzine Mal_Tab 5mg'): 37,
#  ('SR5 2LT', 'FastClix Lancets 0.3mm/30 Gauge'): 31,
#  ('BB7 2JG', 'Lisinopril_Tab 5mg'): 40,
#  ('B70 7AW', 'Sildenafil_Tab 100mg'): 67,
#  ('NW10 8RY', 'Chlorphenamine Mal_Oral Soln 2mg/5ml'): 18,
#  ('LE5 3GH', 'Juvela_G/F W/F Fusilli'): 2,
#  ('LE5 3GH', 'Ebesque XL_Tab 200mg'): 2,
#  ('B11 4BW', 'Olanzapine_Tab 20mg'): 6,
#  ('BL1 8TU', 'Apixaban_Tab 5mg'): 49,
#  ('OL11 1DN', 'Sertraline HCl_Tab 100mg'): 76,
#  ('L5 0QW', 'Dipyridamole_Cap 200mg M/R'): 10,
#  ('B70 7AW', 'Ibuprofen_Tab 400mg'): 59,
#  ('CW5 5NX', 'Senna_Oral Soln 7.5mg/5ml S/F'): 7,
#  ('BB3 1PY', 'Balneum Plus_Bath Oil'): 3,
#  ('TW13 4GU', 'Fucibet_Crm'): 9,
#  ('ME8 8AA', 'Citalopram Hydrob_Tab 40mg'): 65,
#  ('CW5 5NX', 'Gedarel_Tab 30/150mcg'): 3,
#  ('YO16 4LZ', 'Fybogel_Gran Sach 3.5g Plain G/F S/F'): 14,
#  ('SK11 6JL', 'Atenolol_Tab 25mg'): 302,
#  ('HU7 4DW', 'Aveeno_Body Wash'): 11,
#  ('WS3 3JP', 'Fultium-D3_Cap 800u'): 28,
#  ('SS0 7AF', 'Gabapentin_Cap 400mg'): 3,
#  ('B21 9RY', 'Pravastatin Sod_Tab 20mg'): 33,
#  ('TW8 8DS', 'Phyllocontin Continus_Tab 225mg'): 34,
#  ('SS9 5UU', 'Diltiazem HCl_Tab 60mg M/R'): 8,
#  ('M30 0NU', 'Omnican Fine Needles Pen Inj Screw On 6m'): 11,
#  ('TW3 3LN', 'Mebeverine HCl_Tab 135mg'): 44,
#  ('TS24 7PW', 'Diprosalic_Scalp Applic 0.05%/2%'): 3,
#  ('TS24 7PW', 'Peristeen Accessory Unit'): 3,
#  ('OL1 1NL', 'Buscopan_Tab 10mg'): 16,
#  ('M35 0AD', 'E45_Itch Relief Crm'): 13,
#  ('KT6 6EZ', 'Systane Hydroxypropyl Guar Eye Dps 10ml'): 9,
#  ('B18 7AL', 'Pregabalin_Cap 150mg'): 4,
#  ('SK11 6JL', 'Clopidogrel_Tab 75mg'): 910,
#  ('NE24 1DX', 'Nitrofurantoin_Cap 100mg'): 5,
#  ('WD18 0JP', 'Lansoprazole_Orodisper Tab 15mg'): 4,
#  ('FY2 0JG', 'Cefalexin_Oral Susp 250mg/5ml'): 5,
#  ('L31 0DJ', 'Nexium_Tab 20mg'): 5,
#  ('HG1 5AR', 'Maxidex_Eye Dps 0.1%'): 3,
#  ('LS9 9EF', 'Solpadol_Capl 30mg/500mg'): 8,
#  ('CW7 1AT', 'Premique_Tab 0.625mg/5mg'): 3,
#  ('BB4 5SL', 'Lansoprazole_Cap 15mg (E/C Gran)'): 81,
#  ('L7 6HD', 'Losartan Pot_Tab 50mg'): 43,
#  ('SR4 7XF', 'Linagliptin_Tab 5mg'): 56,
#  ('TN24 0GP', 'Levothyrox Sod_Tab 50mcg'): 21,
#  ('NW10 8RY', 'Atenolol_Tab 25mg'): 14,
#  ('BB3 1PY', 'Fluoxetine HCl_Cap 20mg'): 520,
#  ('WN2 5NG', 'Levetiracetam_Tab 1g'): 7,
#  ('WN3 5HL', 'Nicorette_QuickMist Oromucosal P/Spy'): 8,
#  ('TS17 0EE', 'Trihexyphenidyl HCl_Tab 2mg'): 3,
#  ('BB8 0JZ', 'Conotrane_Crm'): 7,
#  ('LN2 2JP', 'Microlet Lancets 0.5mm/28 Gauge'): 21,
#  ('TW3 3LN', 'Sinemet_Tab 12.5mg/50mg'): 9,
#  ('W10 6DZ', 'Gaviscon Advance_Liq (Aniseed) (Reckitt)'): 6,
#  ('M35 0AD', 'Risperidone_Tab 1mg'): 18,
#  ('TW3 3LN', 'Timodine_Crm'): 19,
#  ('KT6 6EZ', 'Seretide 125_Evohaler 125mcg/25mcg(120D)'): 15,
#  ('DN34 4GB', 'Valsartan_Cap 80mg'): 20,
#  ('GU9 9QS', 'DebriSoft 10cm x 10cm Physical Debrideme'): 2,
#  ('B23 6DJ', 'Oramorph_Oral Soln 10mg/5ml'): 17,
#  ('WS3 3JP', 'Rotigotine_Transdermal Patch 8mg/24hrs'): 3,
#  ('S65 1DA', 'Ciprofloxacin_Tab 500mg'): 14,
#  ('TN24 0GP', 'Aciclovir_Tab 800mg'): 75,
#  ('FY7 8GU', 'Omeprazole_Cap E/C 20mg'): 1179,
#  ('SM3 8EP', 'Bisoprolol Fumar_Tab 3.75mg'): 30,
#  ('PL7 1AD', 'Empagliflozin_Tab 10mg'): 10,
#  ('LS9 9EF', 'Nutriprem 2_Pdr'): 8,
#  ('BL9 0SN', 'Etoricoxib_Tab 60mg'): 5,
#  ('SK6 1ND', 'Dosulepin HCl_Cap 25mg'): 10,
#  ('LE10 1DS', 'Levetiracetam_Tab 1g'): 14,
#  ('BL1 8TU', 'Loratadine_Oral Soln 5mg/5ml'): 7,
#  ('LE10 1DS', 'Melatonin_Tab 2mg M/R'): 18,
#  ('TS1 2NX', 'Proctosedyl_Oint'): 4,
#  ('CT11 8AD', 'Paramax_Tab'): 4,
#  ('NE24 1DX', 'Ensure Plus_Milkshake Style Liq(10 Flav)'): 96,
#  ('SS8 0JA', 'NovoFine Needles Pen Inj Screw On 6mm'): 9,
#  ('HU7 4DW', 'Muse_Transurethral System Stick 1mg'): 4,
#  ('HA3 7LT', 'Betameth Val_Oint 0.025% (1 in 4)'): 3,
#  ('ME8 8AA', 'Aerochamber Plus + Adult/Child/Infant Ma'): 22,
#  ('S65 1DA', 'Enalapril Mal_Tab 10mg'): 29,
#  ('TS17 0EE', 'Prostap 3_DCS Inj 11.25mg Dil + Pfs'): 8,
#  ('DA1 2HA', 'Duac_Once Daily Gel (3% and 1%)'): 22,
#  ('BH23 3AF', 'Trazodone HCl_Oral Liq 50mg/5ml S/F'): 5,
#  ('SE15 5LJ', 'BD Microfine+ Needles Pen Inj Screw On 8'): 5,
#  ('WV13 2DR', 'Amisulpride_Tab 200mg'): 5,
#  ('S74 9AF', 'Celecoxib_Cap 100mg'): 5,
#  ('B18 7AL', 'Sod Feredetate_Oral Soln 190mg/5ml S/F'): 12,
#  ('BB2 1AX', 'Water For Inj_10ml Amp'): 5,
#  ('GL50 4DP', 'Movicol Plain_Pdr Sach 13.7g'): 24,
#  ('CW1 3AW', 'Nexium_Tab 20mg'): 7,
#  ('BB9 7SR', 'Selsun_Shampoo 2.5%'): 4,
#  ('L31 0DJ', 'Amiodarone HCl_Tab 100mg'): 7,
#  ('FY4 1TJ', 'Depo-Medrone_Inj 40mg/ml 2ml Vl'): 23,
#  ('SE1 6JP', 'Lisinopril_Tab 10mg'): 45,
#  ('BL9 0NJ', 'Ensure Plus Advance_Liq (5 Flav)'): 3,
#  ('BB11 2DL', 'Temazepam_Tab 20mg'): 3,
#  ('HG1 5AR', 'Clotrimazole_Pess 500mg/Crm 2%'): 9,
#  ('BB9 7SR', 'Adcal-D3_Dissolve Tab Eff 1.5g/400u(Lem)'): 2,
#  ('WA9 1LN', 'Trazodone HCl_Cap 50mg'): 6,
#  ('SR4 7XF', 'Salmeterol_Inha 25mcg (120 D) CFF'): 19,
#  ('NG7 5HY', 'Ramipril_Cap 5mg'): 134,
#  ('B70 7AW', 'Clobet But_Oint 0.05%'): 29,
#  ('L7 6HD', 'Regurin XL_Cap 60mg'): 2,
#  ('LE5 3GH', 'Prempak-C_C/Pk Tab 625mcg/150mcg'): 4,
#  ('LE5 3GH', 'Nitrofurantoin_Tab 100mg'): 18,
#  ('TR1 2JA', 'Doublebase_Emollient Shower Gel'): 7,
#  ('M11 4EJ', 'Doxazosin Mesil_Tab 4mg'): 91,
#  ('SK6 1ND', 'Oxybutynin HCl_Tab 5mg'): 11,
#  ('BB11 2DL', 'Swabs 10cm x 10cm Fabric Filmated Non-Wo'): 2,
#  ('NE37 2PU', 'Budesonide_Aq Nsl Spy 64mcg (120 D)'): 2,
#  ('SS9 5UU', 'Glyceryl Trinit_Sub A/Spy 400mcg (180D)'): 18,
#  ('DN34 4GB', 'Levothyrox Sod_Tab 25mcg'): 520,
#  ('HU7 4DW', 'Emulsif_Oint'): 3,
#  ('BL9 0NJ', 'Alfacalcidol_Cap 500ng'): 6,
#  ('NE24 1DX', 'Hyoscine_Skin Patch 1mg/72hrs'): 6,
#  ('TS17 0EE', 'Ursodeoxycholic Acid_Tab 150mg'): 3,
#  ('KT6 6EZ', 'Furosemide_Tab 40mg'): 314,
#  ('BB9 7SR', 'Carvedilol_Tab 6.25mg'): 2,
#  ('SK6 1ND', 'Lamotrigine_Tab Disper 25mg S/F'): 2,
#  ('WA9 1LN', 'Nitrofurantoin_Tab 100mg'): 2,
#  ('TS3 6AL', 'Adalat LA 60_Tab 60mg'): 8,
#  ('GU9 9QS', 'Viscotears_Eye Gel 2mg/g 0.6ml Ud'): 4,
#  ('WA7 1AB', 'Dermol 500_Lot'): 39,
#  ('TS1 2NX', 'Quetiapine_Tab 300mg M/R'): 6,
#  ('BB7 2JG', 'Tears Naturale_Eye Dps'): 9,
#  ('SR5 2LT', 'BGStar Ultra-Thin Lancets 0.20mm/33 Gaug'): 5,
#  ('DN34 4GB', 'Fultium-D3_Cap 800u'): 18,
#  ('LN2 2JP', 'Nortriptyline_Tab 10mg'): 12,
#  ('SE1 6JP', 'Symbicort_Turbohaler 100mcg/6mcg (120 D)'): 3,
#  ('DA1 2HA', 'Cutimed Sorbact Gel 7.5cm x 7.5cm Wound'): 3,
#  ('N9 7HD', 'Pregabalin_Cap 300mg'): 3,
#  ('B11 4BW', 'PaediaSure Peptide_Liq'): 2,
#  ('TS10 4NW', 'Ibuprofen_Tab 400mg'): 134,
#  ('OL11 1DN', 'Nitrazepam_Tab 5mg'): 8,
#  ('YO16 4LZ', 'Esomeprazole_Cap E/C 20mg'): 13,
#  ('GU9 9QS', 'Apixaban_Tab 5mg'): 63,
#  ('BL1 8TU', 'Carbamazepine_Tab 100mg'): 5,
#  ('TS1 2NX', 'Nifedipine_Tab 30mg M/R'): 3,
#  ('TS1 2NX', 'Ferr Glucon_Tab 300mg'): 9,
#  ('BL3 5HP', 'Gaviscon Advance_Tab Chble Mint(Reckitt)'): 14,
#  ('OL9 7AY', 'Colecal & Calc_Tab 200u/750mg'): 9,
#  ('CB9 8HF', 'Mesalazine_Gran Sach 500mg M/R'): 2,
#  ('SS8 0JA', 'Co-Codamol_Tab 8mg/500mg'): 126,
#  ('BD3 8QH', 'FastClix Lancets 0.3mm/30 Gauge'): 18,
#  ('B18 7AL', 'Systane Hydroxypropyl Guar Eye Dps 10ml'): 10,
#  ('LE18 2EW', 'Tamsulosin/Dutasteride HCl_Cap 0.4/0.5mg'): 8,
#  ('ST3 6AB', 'Ranitidine HCl_Tab 300mg'): 20,
#  ('CW7 1AT', 'Omnican Fine Needles Pen Inj Screw On 6m'): 8,
#  ('L31 0DJ', 'BD Micro-Fine + Lancets 0.3mm/30 Gauge'): 2,
#  ('FY7 8GU', 'Phenytoin_Sod Cap 50mg'): 2,
#  ('SK11 6JL', 'Estradiol_Val Tab 1mg'): 13,
#  ('HG1 5AR', 'Blumont Carbomer 0.2% Eye Gel'): 5,
#  ('HU7 4DW', 'Sulfasalazine_Tab 500mg'): 16,
#  ('CV1 4FS', 'Venlafaxine_Tab 75mg'): 60,
#  ('SK11 6JL', 'Esomeprazole_Cap E/C 20mg'): 15,
#  ('NN16 8DN', 'Sumatriptan_Inj 6mg/0.5ml Pf Pen'): 2,
#  ('TS1 2NX', 'Aerochamber Plus + Adult/Child/Infant Ma'): 22,
#  ('SS13 3HQ', 'Calcichew D3 Fte_Tab Chble'): 3,
#  ('LN2 2JP', 'Allevyn Ag Gentle Border 10cmx10cm Wound'): 3,
#  ('FY4 1TJ', 'Paroxetine HCl_Tab 20mg'): 42,
#  ('LS9 9EF', 'Sertraline HCl_Tab 50mg'): 380,
#  ('B21 9RY', 'Terbut Sulf_B/A Inha 500mcg (100 D)'): 9,
#  ('SE15 5LJ', 'Hydrocort_Oint 1%'): 24,
#  ('BB8 0JZ', 'Alimemazine Tart_Tab 10mg'): 6,
#  ('NE38 7NQ', 'Fenofibrate_Cap 200mg (Micronised)'): 38,
#  ('KT6 6EZ', 'Seretide 250_Accuhaler 250mcg/50mcg(60D)'): 5,
#  ('SS8 0JA', 'Sod Valpr_Tab 500mg M/R'): 2,
#  ('HU7 4DW', 'Bezafibrate_Tab 400mg M/R'): 8,
#  ('CT11 8AD', 'Citalopram Hydrob_Tab 40mg'): 129,
#  ('DN22 7XF', 'Esomeprazole_Cap E/C 40mg'): 27,
#  ('LE18 2EW', 'E45_Crm'): 20,
#  ('B18 7AL', 'Atorvastatin_Tab 80mg'): 50,
#  ('FY2 0JG', 'Glyceryl Trinit_Sub P/Spy 400mcg (180D)'): 84,
#  ('FY4 1TJ', 'Emla_Crm 5%'): 6,
#  ('HU7 4DW', 'Movicol Plain_Paed Pdr Sach 6.9g'): 20,
#  ('LA1 1PN', 'Atenolol_Tab 25mg'): 174,
#  ('OL4 1YN', 'Naftidrofuryl Oxal_Cap 100mg'): 5,
#  ('YO16 4LZ', 'Evorel 50_Patch'): 3,
#  ('HU7 4DW', 'Coloplast_Sensura S/Seal M/chamb Urost B'): 3,
#  ('BL1 8TU', 'Benzydamine HCl_Spy 0.15% 30ml S/F'): 11,
#  ('M30 0NU', 'CosmoCol_Oral Pdr Sach (Orng Lem & Lim)'): 2,
#  ('CV1 4FS', 'Morph Sulf_Inj 10mg/1ml Amp'): 5,
#  ('TN24 0GP', 'Zolpidem Tart_Tab 10mg'): 16,
#  ('S74 9AF', 'Folic Acid_Tab 400mcg'): 17,
#  ('SE15 5LJ', 'Fusidic Acid_Viscous Eye Dps 1%'): 13,
#  ('TN34 1BA', 'Ramipril_Tab 10mg'): 2,
#  ('HA3 7LT', 'Diclofenac Sod_Gel 1.16%'): 17,
#  ('TR1 2JA', 'Beconase_Aq Nsl Spy 50mcg (200 D) 22g'): 12,
#  ('LN2 2JP', 'Mebeverine HCl_Tab 135mg'): 83,
#  ('M35 0AD', 'Quinine Bisulf_Tab 300mg'): 52,
#  ('BB11 2DL', 'Nicotine_Transdermal Patch 15mg/16hrs'): 4,
#  ('TN34 1BA', 'Almus Sod Chlor 0.9% Nsl Dps'): 13,
#  ('WS10 8SY', 'Simvastatin_Tab 20mg'): 133,
#  ('BB11 2DL', 'Desmopressin Acet_Oral Lyoph 120mcg'): 2,
#  ('TR1 2JA', 'Prednisolone_Tab E/C 5mg'): 44,
#  ('TS17 0EE', 'Flutiform_Inha 125/5mcg (120 D)'): 5,
#  ('FY7 8GU', 'Pioglitazone HCl_Tab 30mg'): 8,
#  ('HA3 7LT', 'Questran Light_Sach 9g (4g Of Ingredient'): 2,
#  ('NE10 9QG', 'Chlorphenamine Mal_Oral Soln 2mg/5ml S/F'): 6,
#  ('BB8 0JZ', 'Microlet Lancets 0.5mm/28 Gauge'): 52,
#  ('CW5 5NX', 'Fresubin 2kcal_Drink (6 Flav)'): 7,
#  ('SE15 5LJ', 'Stexerol-D3_Tab 25 000u'): 21,
#  ('PL7 1AD', 'Unguentum M_Crm'): 9,
#  ('SR4 7XF', 'Isosorbide Mononit_Tab 40mg M/R'): 2,
#  ('HG1 5AR', 'Daktacort_Crm 2%/1%'): 9,
#  ('TS3 6AL', 'Nicorandil_Tab 20mg'): 52,
#  ('LE5 3GH', 'Angitil SR 120_Cap 120mg'): 4,
#  ('DN22 7XF', 'Aveeno_Crm'): 27,
#  ('SM3 8EP', 'Alfuzosin HCl_Tab 10mg M/R'): 12,
#  ('LE18 2EW', 'Glutafin_G/F Fibre Bread (Cut)'): 4,
#  ('SS0 7AF', 'Dermol_Crm'): 11,
#  ('RM3 9SU', 'Medikinet XL_Cap 10mg'): 13,
#  ('BD3 8QH', 'Gaviscon Advance_Tab Chble Mint(Reckitt)'): 6,
#  ('TS17 0EE', 'Dalivit_Dps'): 8,
#  ('TS3 6AL', 'Warfarin Sod_Tab 3mg'): 110,
#  ('LA1 1PN', 'Symbicort_Turbohaler 200mcg/6mcg (120 D)'): 29,
#  ('B23 6DJ', 'Azathioprine_Tab 25mg'): 4,
#  ('SR4 7XF', 'Erythromycin_Ethylsuc Susp 250mg/5ml S/F'): 3,
#  ('BL3 5HP', 'Ventolin_Evohaler 100mcg (200 D)'): 121,
#  ('TN34 1BA', 'Softclix Lancets 0.4mm/28 Gauge'): 2,
#  ('WA9 1LN', 'Vensir XL_Cap 225mg'): 5,
#  ('GL1 3PX', 'Cabergoline_Tab 0.5mg'): 2,
#  ...}

# %%
len(total_items_by_bnf_post)
# Out:
# 141196

# %%
assert len(total_items_by_bnf_post) == 141196

# %% [markdown]
# Let's use `total_by_item_post` to find the maximum item total for each postal code. To do this, we will want to regroup `total_by_item_post` by `'post_code'` only, not by `('post_code', 'bnf_name')`. First let's turn `total_by_item_post` into a list of dictionaries (similar to `scripts` or `practices`) and then group it by `'post_code'`. You should have 118 groups in `total_by_item_post` after grouping it by `'post_code'`.

# %%
total_items = []
for (post_code, bnf_name), total in list(total_items_by_bnf_post.items()):
    new_dict = {'post_code': post_code,
                'bnf_name' : bnf_name,
                'total' : total}
    total_items.append(new_dict)

# %%
total_items[:2]
# Out:
# [{'post_code': 'LS9 9EF',
#   'bnf_name': 'Sod Algin/Pot Bicarb_Susp S/F',
#   'total': 79},
#  {'post_code': 'WS3 3JP', 'bnf_name': 'Felodipine_Tab 2.5mg M/R', 'total': 37}]

# %%
total_items_by_post = group_by_field(total_items, ('post_code',))

# %%
total_items_by_post

# %%
len(total_items_by_post)
# Out:
# 118

# %%
assert len(total_items_by_post) == 118

# %% [markdown]
# Now we will aggregate the groups in `total_by_item_post` to create `max_item_by_post`. Some `'bnf_name'` have the same item total within a given postal code. Therefore, if more than one `'bnf_name'` has the maximum item total in a given postal code, we'll take the alphabetically first `'bnf_name'`. We can do this by [sorting](https://docs.python.org/2.7/howto/sorting.html) each group according to the item total and `'bnf_name'`.

# %%
max_item_by_post = max(total_items_by_post)
max_item_by_post
# Out:
# ('YO16 4LZ',)

# %%
test_list = total_items_by_post[('YO16 4LZ',)]
test_list
# Out:
# [{'post_code': 'YO16 4LZ', 'bnf_name': 'Nifedipine_Cap 10mg', 'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Carvedilol_Tab 6.25mg', 'total': 38},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Aspirin_Tab 75mg', 'total': 33},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Tamsulosin HCl_Cap 400mcg M/R',
#   'total': 448},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Zapain_Tab 30mg/500mg', 'total': 225},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Buprenorphine_Tab Subling 400mcg S/F',
#   'total': 6},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Fybogel_Gran Sach 3.5g Plain G/F S/F',
#   'total': 14},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Esomeprazole_Cap E/C 20mg',
#   'total': 13},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Evorel 50_Patch', 'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Solaraze_Gel 3%', 'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Paracet_Cap 500mg', 'total': 62},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Co-Beneldopa_Tab Disper 12.5mg/50mg S/F',
#   'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Lansoprazole_Cap 15mg (E/C Gran)',
#   'total': 708},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Tramadol HCl_Tab 50mg M/R',
#   'total': 17},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Lamotrigine_Tab 50mg', 'total': 37},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Aveeno_Crm', 'total': 48},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Limb Seal-Tight Adult Foot/Ankle Wound C',
#   'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Naproxen_Tab 250mg', 'total': 56},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Verapamil HCl_Tab 120mg', 'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Ins Humalog Mix 50_KwikPen 100u/ml 3mlPf',
#   'total': 20},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Tylex_Cap 30mg/500mg', 'total': 8},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Haloperidol_Inj 5mg/ml 1ml Amp',
#   'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Promethazine HCl_Tab 25mg',
#   'total': 22},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Lyrica_Cap 75mg', 'total': 42},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Risperidone_Orodisper Tab 500mcg S/F',
#   'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Perindopril Erbumine_Tab 2mg',
#   'total': 265},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Ipratrop Brom_Aq Nsl Spy 21mcg (180D)CFF',
#   'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Clotrimazole_Pess 500mg', 'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Anoro Ellipta_Inha 55mcg/22mcg (30D)',
#   'total': 75},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Dermol 200_Shower Emollient',
#   'total': 41},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Haloperidol_Tab 5mg', 'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Aveeno_Bath Oil', 'total': 14},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Octasa_MR Tab E/C 400mg', 'total': 15},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Angitil SR 90_Cap 90mg', 'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Fluticasone Fur_Nsl Spy 27.5mcg (120D)',
#   'total': 25},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Lacosamide_Tab 200mg', 'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Bisoprolol Fumar_Tab 3.75mg',
#   'total': 35},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Clarithromycin_Tab 250mg',
#   'total': 22},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Sumatriptan_Aq Nsl Spy 10mg/0.1ml Ud',
#   'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Peptac_Liq (Aniseed) S/F',
#   'total': 90},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Adalat Ret_Tab 10mg', 'total': 9},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Respond_OstoMart OstoMist Blackberry P/S',
#   'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Etoricoxib_Tab 60mg', 'total': 36},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Timolol_Tab 10mg', 'total': 12},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Marol_Tab 200mg M/R (Teva)',
#   'total': 62},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Proctosedyl_Oint', 'total': 5},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Glimepiride_Tab 4mg', 'total': 11},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Nebido_Inj 1000mg/4ml Vl', 'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Marol_Tab 100mg M/R (Teva)',
#   'total': 50},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Baclofen_Oral Soln 5mg/5ml S/F',
#   'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Betnovate RD_Oint 0.025%', 'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Glyceryl Trinit_Sub P/Spy 400mcg (200D)',
#   'total': 30},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Bisoprolol Fumar_Tab 2.5mg',
#   'total': 492},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Tildiem Ret 120_Tab 120mg',
#   'total': 16},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Anusol HC_Oint', 'total': 8},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'AMI_Suportx Ostomy/Hernia Easy Peel Supp',
#   'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Aveeno_Lot', 'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Carbomer 980_Gel Eye Dps 0.2%',
#   'total': 39},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Mebeverine HCl_Tab 135mg',
#   'total': 108},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Cetraben_Bath Oil', 'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Fluconazole_Cap 150mg', 'total': 14},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Ins Tresiba_FlexTouch 100u/ml 3ml Pf Pen',
#   'total': 12},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Aymes Shake_Pdr (Banana)', 'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Pravastatin Sod_Tab 10mg',
#   'total': 64},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Perindopril Erbumine_Tab 8mg',
#   'total': 271},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Sod Bicarb_Cap 500mg', 'total': 8},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Fostair NEXThaler_Inh 100mcg/6mcg (120D)',
#   'total': 16},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Ins NovoMix 30_Penfill 100u/ml 3ml Cart',
#   'total': 9},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Betameth Val_Crm 0.1%', 'total': 27},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Thiamine HCl_Tab 50mg', 'total': 11},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Oxybutynin HCl_Tab 5mg M/R',
#   'total': 8},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Phenytoin_Sod Tab 100mg', 'total': 5},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Unspec Drug Code_', 'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Omeprazole_Tab Disper 10mg (E/C Pellets)',
#   'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Alimemazine Tart_Tab 10mg',
#   'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Ins Lantus_100u/ml 3ml Cart',
#   'total': 18},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Laxido_Paed Plain Oral Pdr Sach 6.9g',
#   'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Nitrofurantoin_Cap 100mg M/R',
#   'total': 8},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Epaderm Oint', 'total': 24},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Primidone_Tab 250mg', 'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Seretide 50_Evohaler 50mcg/25mcg (120 D)',
#   'total': 10},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Allopurinol_Tab 300mg', 'total': 124},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Salts_SecuPlast Hydro', 'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Simvastatin_Tab 40mg', 'total': 945},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Bard_Flip-Flo Cath Valve', 'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Ins NovoRapid_FlexPen 100u/ml 3ml Pf Pen',
#   'total': 33},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Nutramigen 2 LIPIL_Pdr', 'total': 6},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Ganfort_Eye Dps 300mcg/5mg',
#   'total': 16},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Oxytetracycline_Tab 250mg',
#   'total': 13},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Scheriproct_Suppos', 'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Felodipine_Tab 5mg M/R', 'total': 92},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'SunVit-D3 1 000_Tab', 'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Allopurinol_Tab 100mg', 'total': 183},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Ketorolac Trometamol_Eye Dps 0.5%',
#   'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'NovoFine Needles Pen Inj Screw On 6mm',
#   'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Sylk Vag Moist 40g Tube', 'total': 6},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Oilatum_Shower Gel Fragrance Free',
#   'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Temazepam_Tab 10mg', 'total': 44},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Bisoprolol Fumar_Tab 5mg',
#   'total': 284},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Betameth Val/Fusidic Acid_Crm 0.1%/2%',
#   'total': 16},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Gaviscon Double Action_Tab Chble',
#   'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Salazopyrin-En_Tab 500mg', 'total': 6},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'CliniSupplies_ProSys Leg Bag Ster 500ml',
#   'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Colecal & Calc_Tab Chble 200u/1.25g',
#   'total': 12},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Isosorbide Mononit_Tab 50mg M/R',
#   'total': 16},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Sod Valpr_Oral Soln 200mg/5ml S/F',
#   'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Zoladex_Implant 3.6mg SafeSystem Pfs',
#   'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Rosuvastatin Calc_Tab 20mg',
#   'total': 21},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Qvar 100 E-Breathe_Inha 100mcg (200 D)',
#   'total': 7},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Kalcipos-D_Tab Chble 800u/500mg',
#   'total': 5},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Microgynon 30 ED_Tab', 'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Adalat_Cap 5mg', 'total': 7},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'FreeStyle Lancets 0.5mm/28 Gauge',
#   'total': 7},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Nasacort_Nsl Spy 55mcg (120D)',
#   'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Half Sinemet CR_Tab 125mg',
#   'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Sno Tears 1.4% Polyvinyl Alcohol Eye Dps',
#   'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Furosemide_Oral Soln 40mg/5ml S/F',
#   'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Marol_Tab 150mg M/R (Teva)',
#   'total': 9},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'QV Crm', 'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Trazodone HCl_Cap 50mg', 'total': 19},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Fusidic Acid_Viscous Eye Dps 1%',
#   'total': 11},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Mycophenolate Mofetil_Cap 250mg',
#   'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Spiriva Respimat_Inha 2.5mcg (60D) + Dev',
#   'total': 40},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Etodolac_Tab 600mg M/R', 'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Dovobet_Oint 0.005%/0.05%',
#   'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Victoza_Inj 6mg/ml 3ml PF Pen',
#   'total': 14},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Sod Valpr_Tab 100mg', 'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Instillagel_Gel 11ml Pfs', 'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Timolol_Gel Eye Dps 0.25%',
#   'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Calogen_Emuls (Neutral)', 'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Pulmicort_Turbohaler 200mcg (100 D)',
#   'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Repaglinide_Tab 1mg', 'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Mirtazapine_Orodisper Tab 15mg',
#   'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Adalat Ret_Tab 20mg', 'total': 9},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Colecal & Calc_Tab Chble 400u/1.25g',
#   'total': 134},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Timolol_Gel Eye Dps 1mg/g 0.4g Ud P/F',
#   'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Glyceryl Trinit_Patch 10mg/24hrs',
#   'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Sitagliptin_Tab 50mg', 'total': 9},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Zomorph_Cap 30mg', 'total': 33},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Tubigrip 8.75cm x 1m Stkntte Elasctd Tub',
#   'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Saxagliptin_Tab 5mg', 'total': 5},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Piroxicam_Gel 0.5%', 'total': 73},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Emulsif_Oint', 'total': 6},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Non-Woven Fabric Swab 10cm x 10cm Non-St',
#   'total': 9},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Aveeno_Body Wash', 'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Topiramate_Tab 100mg', 'total': 12},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Enalapril Mal_Tab 2.5mg', 'total': 27},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Liraglutide_Inj 6mg/ml 3ml PF Pen',
#   'total': 54},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Abidec_Dps', 'total': 7},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Aclidinium Brom_Pdr For Inh 375mcg (60D)',
#   'total': 7},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Tegretol_Tab 200mg', 'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Adcal-D3_Dissolve Tab Eff 1.5g/400u(Lem)',
#   'total': 6},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Longtec_Tab 10mg M/R', 'total': 11},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'B.Braun Actreen Fle Mini Nelaton 10-14 (',
#   'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Propranolol HCl_Tab 10mg',
#   'total': 23},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Mirtazapine_Orodisper Tab 30mg',
#   'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Ipratrop Brom_Inh Soln 500mcg/2ml Ud',
#   'total': 7},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Slo-Phyllin_Cap 250mg', 'total': 5},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Oxazepam_Tab 15mg', 'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Seebri_Breezhaler Inh Cap 55mcg + Dev',
#   'total': 8},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Olanzapine_Tab 2.5mg', 'total': 12},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'C D Medical_Peel Easy Adh Remover Spy 50',
#   'total': 8},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Carbomer 980_Gel Eye Dps 0.2% 0.6mlUdP/F',
#   'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Bard_Uriplan Leg Bag 30cm Inlet Tube 500',
#   'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Tibolone_Tab 2.5mg', 'total': 19},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Solpadol_Tab Eff 30mg/500mg',
#   'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Cetirizine HCl_Oral Soln 1mg/1ml S/F',
#   'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Bezafibrate_Tab 200mg', 'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Pioglitazone HCl_Tab 45mg',
#   'total': 6},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Paliperidone_Inj 100mg/1ml Pfs',
#   'total': 6},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Betahistine HCl_Tab 8mg', 'total': 23},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Isosorbide Mononit_Tab 25mg M/R',
#   'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Ramipril_Oral Soln 2.5mg/5ml S/F',
#   'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Balneum Plus_Bath Oil', 'total': 5},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Arcoxia_Tab 60mg', 'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Sod Algin/Pot Bicarb_Susp S/F',
#   'total': 12},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Sirdupla_Inh 250mcg/25mcg (120D)',
#   'total': 9},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Class 1 M/M C/Kt B/Knee Stkn Elas Hose',
#   'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Sotalol HCl_Tab 80mg', 'total': 9},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Bisacodyl_Tab E/C 5mg', 'total': 19},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Dalteparin Sod_Inj 25 000u/ml 0.5ml Pfs',
#   'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Voltarol Emulgel_Aq Gel 1.16%',
#   'total': 17},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Imiquimod_Crm 5% Sach 250mg',
#   'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Timodine_Crm', 'total': 20},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Plavix_Tab 75mg', 'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Betameth Sod Phos_Ear/Eye/Nsl Dps 0.1%',
#   'total': 14},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Cyclizine HCl_Tab 50mg', 'total': 24},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Uniphyllin Continus_Tab 400mg',
#   'total': 19},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Zolpidem Tart_Tab 5mg', 'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Ketoconazole_Shampoo 2%', 'total': 15},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Mirtazapine_Orodisper Tab 45mg',
#   'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Esomeprazole_Cap E/C 40mg',
#   'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Acamprosate Calc_Tab E/C 333mg',
#   'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Sertraline HCl_Tab 100mg',
#   'total': 155},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Estraderm MX 25_Patch', 'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Phenytoin_Sod Cap 300mg', 'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Dihydrocodeine Tart_Tab 30mg',
#   'total': 84},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Metformin HCl_Tab 500mg',
#   'total': 756},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Ipratrop Brom_Inha 20mcg (200 D) CFF',
#   'total': 15},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Cetraben Crm 500g', 'total': 24},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Lumigan_Eye Dps 100mcg/ml',
#   'total': 35},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Calcipotriol_Oint 50mcg/1g',
#   'total': 13},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Tamsulosin HCl_Tab 400mcg M/R',
#   'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Levothyrox Sod_Tab 25mcg',
#   'total': 553},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Chlorpromazine HCl_Tab 25mg',
#   'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Colecal_Tab 800u', 'total': 42},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Dermovate_Oint 0.05%', 'total': 6},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Adizem-XL_Cap 120mg', 'total': 10},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Lipitor_Tab 20mg', 'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Metronidazole_Tab 400mg', 'total': 19},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Acetazolamide_Tab 250mg', 'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Beclomet Diprop_Nsl Spy 50mcg (200 D)',
#   'total': 161},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Liquifilm 1.4% Polyvinyl Alcohol Eye Dps',
#   'total': 28},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'CliniFix Tube Holder 140mm x 40mm Cath A',
#   'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Naproxen_Tab E/C 250mg', 'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Diamorph HCl_Inj 5mg Amp', 'total': 5},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Nifedipine_Cap 5mg', 'total': 6},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Donepezil HCl_Tab 5mg', 'total': 16},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Zoladex LA_Implant 10.8mg SafeSystem Pfs',
#   'total': 10},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Doxazosin Mesil_Tab 2mg', 'total': 55},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Colecal/Calc_Eff Gran Sach 440u/1.25g 4g',
#   'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Sildenafil_Tab 25mg', 'total': 5},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Aymes Shake_Pdr (Sbery)', 'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Metformin HCl_Tab 1g M/R',
#   'total': 71},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Clonazepam_Tab 2mg', 'total': 9},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Erythromycin_Ethylsuc Susp 250mg/5ml',
#   'total': 10},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Xalatan_Eye Dps 50mcg/ml', 'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Celecoxib_Cap 100mg', 'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'total': 10},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Tramadol HCl_Cap 200mg M/R',
#   'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Monomil XL_Tab 60mg', 'total': 126},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Nasofan_Aq Nsl Spy 50mcg (150 D)',
#   'total': 7},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Acti-Fast 2-Way Stch 7.5cmx5m (Blue) Stk',
#   'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Lido_Medic Plastr 5%', 'total': 7},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Prochlpzine Mal_Tab 5mg', 'total': 55},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Adalat LA 20_Tab 20mg', 'total': 7},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Furosemide_Tab 40mg', 'total': 362},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Omacor_Cap', 'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Ins Humalog Mix 50_100u/ml 3ml Cart',
#   'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Lymecycline_Cap 408mg', 'total': 35},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Ranitidine HCl_Tab Eff 150mg',
#   'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Nystaform-HC_Crm', 'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Azithromycin_Tab 250mg', 'total': 16},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Nitrofurantoin_Tab 50mg', 'total': 34},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Co-Codamol_Cap 30mg/500mg',
#   'total': 137},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Doublebase_Emollient Wash Gel',
#   'total': 6},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Pregabalin_Cap 50mg', 'total': 24},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Budesonide/Formoterol Inh B/A 100/6(120D',
#   'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Chloramphen_Eye Dps 0.5%',
#   'total': 26},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Fenofibrate_Cap 267mg (Micronised)',
#   'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Biatain Adh 7.5cm x 7.5cm Wound Dress Po',
#   'total': 5},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Ranolazine_Tab 750mg M/R', 'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Flutiform_Inha 50/5mcg (120 D)',
#   'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'One-Alpha_Cap 500ng', 'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Preservision_Original Cap',
#   'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Movicol_Pdr Sach 13.8g (Lem & Lim)',
#   'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Mezolar Matrix_TransdermalPatch100mcg/hr',
#   'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Evorel 25_Patch', 'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Latanoprost_Eye Dps 50mcg/ml',
#   'total': 184},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Celluvisc_Eye Dps 0.5% 0.4ml Ud',
#   'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Rusch Sympacath AquaFlate Male H/Gel Ctd',
#   'total': 6},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Tolterodine_Tab 1mg', 'total': 7},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'B.Braun Actreen Male Glys Set Nelaton 8-',
#   'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Depo-Provera_Inj 150mg/ml 1ml Pfs',
#   'total': 8},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Bedranol S.R._Cap 80mg (Sandoz)',
#   'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Priadel_Tab 400mg', 'total': 10},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Donepezil HCl_Tab 10mg', 'total': 56},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Cosopt_Ocumeter Plus Eye Dps',
#   'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Citalopram Hydrob_Tab 10mg',
#   'total': 204},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Inadine 5cm x 5cm Povidone Iodine Fabric',
#   'total': 5},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Venlablue XL_Cap 75mg', 'total': 10},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Butec_Transdermal Patch 10mcg/hr',
#   'total': 38},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Exenatide_Inj 10mcg/0.04ml 2.4mlPfs(60D)',
#   'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Kliofem_Tab', 'total': 6},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Candesartan Cilexetil_Tab 2mg',
#   'total': 12},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Oilatum_Gel', 'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Losartan Pot_Tab 25mg', 'total': 124},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Pravastatin Sod_Tab 20mg',
#   'total': 78},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Tegretol Prolonged Release_Tab 200mg M/R',
#   'total': 20},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Lofepramine HCl_Tab 70mg',
#   'total': 10},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Fluticasone/Salmeterol_Inh 50/25mcg 120D',
#   'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Laxido_Oral Pdr Sach (Orange) S/F',
#   'total': 301},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Flumetasone/Clioquinol_Ear Dps 0.02%/1%',
#   'total': 22},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Mobile (Reagent)_Strips', 'total': 25},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Estriol_Crm 0.1% + Applic',
#   'total': 9},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Paracet_Oral Susp Paed 120mg/5ml S/F',
#   'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Fluticasone/Salmeterol_Inh 125/25mcg120D',
#   'total': 18},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Amorolfine HCl_Nail Lacquer Kit 5% 5ml',
#   'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Matrifen_Patch 12mcg/hr', 'total': 21},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Perampanel_Tab 6mg', 'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Heparinoid_Crm 0.3%', 'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Dansac_NovaLife 1 Open Soft Convex Midi',
#   'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Amitriptyline HCl_Tab 50mg',
#   'total': 50},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'DuoDERM Ex Thin 10cm x 10cm Wound Dress',
#   'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Furosemide_Tab 20mg', 'total': 209},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Alogliptin_Tab 25mg', 'total': 21},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Clotrimazole_Crm 10%', 'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Levocetirizine_Tab 5mg', 'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Paracet_Tab Solb 500mg', 'total': 18},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Olanzapine_Tab 7.5mg', 'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Tildiem_Tab 60mg', 'total': 19},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Canagliflozin_Tab 100mg', 'total': 19},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Atorvastatin_Tab 20mg', 'total': 1122},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Cyanocobalamin_Tab 50mcg',
#   'total': 23},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Nystatin_Oral Susp 100 000u/ml',
#   'total': 5},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Telmisartan_Tab 40mg', 'total': 16},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'GlucoMen areo Sensor (Reagent)_Strips',
#   'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Chemydur 60 XL_Tab 60mg', 'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Non-Woven Fabric Swab 7.5cm x 7.5cm Ster',
#   'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Gaviscon_Liq Relief Peppermint',
#   'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Calc Carb_Tab Chble 1.25g (500mg) S/F',
#   'total': 8},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Clomipramine HCl_Tab 75mg M/R',
#   'total': 5},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Fluclox Sod_Cap 500mg', 'total': 94},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Metoclopramide HCl_Tab 10mg',
#   'total': 43},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Mefenamic Acid_Tab 500mg', 'total': 7},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Aciclovir_Tab 400mg', 'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'L.IN.C_LINC-Flo Leg Bag 500ml 30cm Inlet',
#   'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Oilatum Jnr_Crm (Liq)', 'total': 5},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Sharpsafe 1L', 'total': 91},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Prempak-C_C/Pk Tab 625mcg/150mcg',
#   'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Clement Clarke Stnd Range Peak Flow Mete',
#   'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Temazepam_Tab 20mg', 'total': 11},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Nedocromil Sod_Eye Dps Aq 2%',
#   'total': 5},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Diazepam_Tab 2mg', 'total': 86},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Duloxetine HCl_Cap G/R 40mg',
#   'total': 10},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Dalteparin Sod_Inj 25 000u/ml 0.2ml Pfs',
#   'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Budesonide/Formoterol Inh B/A 200/6(120D',
#   'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Loestrin 30_Tab', 'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Maxalt_Melt Oral Lyophilisate Tab 10mg',
#   'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Doublebase_Emollient Shower Gel',
#   'total': 12},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Micralax_Micro-Enem 5ml', 'total': 9},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Sod Valpr_Oral Soln 200mg/5ml',
#   'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Fortisip Compact_Liq (8 Flav)',
#   'total': 45},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Verapamil HCl_Tab 40mg', 'total': 9},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Ins Humulin I_KwikPen 100u/ml 3ml Pf Pen',
#   'total': 5},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Lyrica_Cap 300mg', 'total': 27},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Levothyrox Sod_Tab 50mcg',
#   'total': 507},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'FreeStyle (Reagent)_Strips',
#   'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Calmurid_Crm', 'total': 6},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Biquelle XL_Tab 50mg', 'total': 7},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Sumatriptan_Tab 50mg', 'total': 44},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Half Securon SR_Tab 120mg',
#   'total': 11},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Movelat_Gel', 'total': 14},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Angitil SR 120_Cap 120mg', 'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Chlorhex Glucon_Soln 4%', 'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Drapolene_Crm', 'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Calogen Extra Shots_Emuls (2 Flav)',
#   'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Trospium Chlor_Cap 60mg M/R',
#   'total': 9},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Quinapril HCl_Tab 20mg', 'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Diclofenac Sod_Gel 3%', 'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Oxycodone HCl_Oral Soln 5mg/5ml S/F',
#   'total': 11},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Neoral_Cap 25mg', 'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Otomize_Ear Spy 5ml', 'total': 32},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Premarin_Tab 625mcg', 'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Amoxicillin_Oral Susp 125mg/5ml',
#   'total': 8},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Bicalutamide_Tab 150mg', 'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Gaviscon_Liq Orig Aniseed Relief',
#   'total': 8},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Colecal & Calc_Tab Chble 400u/1.5g',
#   'total': 46},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Fluticasone/Vilanterol_Inha 184/22mcg30D',
#   'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Seretide 250_Evohaler 250mcg/25mcg(120D)',
#   'total': 47},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Fortijuce_Liq (7 Flav)', 'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Hyabak Sod Hyaluronate Eye Dps 10ml P/F',
#   'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Erythromycin/Zn Acet_Lot 40mg/Ml/12mg/ml',
#   'total': 6},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Amantadine HCl_Cap 100mg', 'total': 7},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Alfuzosin HCl_Tab 10mg M/R',
#   'total': 18},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Betameth Val_Scalp Applic 0.1%',
#   'total': 15},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Pneumococcal_Vac 0.5ml Vl (23 Valent)',
#   'total': 28},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Aripiprazole_Tab 10mg', 'total': 8},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Matrifen_Patch 75mcg/hr', 'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Elocon_Oint 0.1%', 'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Thiamine HCl_Tab 100mg', 'total': 115},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'CosmoCol_Paed Oral Pdr Sach 6.9g',
#   'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'H & R_Proshield Plus Skin Prote 115g',
#   'total': 23},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Gabapentin_Tab 600mg', 'total': 20},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Lacidipine_Tab 2mg', 'total': 13},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'BD Microfine+ Needles Pen Inj Screw On 5',
#   'total': 6},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Diazepam_Tab 10mg', 'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Sod Valpr_Tab 300mg M/R', 'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Tegretol Prolonged Release_Tab 400mg M/R',
#   'total': 17},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Dermol 500_Lot', 'total': 16},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Gliclazide_Tab 30mg M/R', 'total': 9},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Indometacin_Cap 25mg', 'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Morphgesic SR_Tab 10mg', 'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Alzest_Skin Patch 9.5mg/24hrs',
#   'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Co-Codamol Eff_Tab 30mg/500mg',
#   'total': 47},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Imipramine HCl_Tab 25mg', 'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Amitriptyline HCl_Tab 10mg',
#   'total': 454},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Sulfasalazine_Tab E/C 500mg',
#   'total': 13},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Zolpidem Tart_Tab 10mg', 'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Paracet/Metoclopramide HCl_Tab 500mg/5mg',
#   'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Hylo-Tear Sod Hyaluronate Eye Dps 0.1% P',
#   'total': 27},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Tegretol_Tab 100mg', 'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Piloc HCl_Eye Dps 2%', 'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Trimethoprim_Tab 100mg', 'total': 9},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Trospium Chlor_Tab 20mg', 'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Sevelamer_Tab 800mg', 'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Colecal & Calc_Tab Eff 400u/1.5g (Lem)',
#   'total': 6},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Coal Tar_Ext Shampoo 5%', 'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Zomorph_Cap 10mg', 'total': 57},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Lipitor_Tab 10mg', 'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Perindopril Erbumine_Tab 4mg',
#   'total': 357},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Venlafaxine_Tab 37.5mg', 'total': 9},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Zapain_Cap 30mg/500mg', 'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Lacri-Lube_Ophth Oint', 'total': 16},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Bisoprolol Fumar_Tab 10mg',
#   'total': 174},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Emla_Crm 5%', 'total': 7},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Glimepiride_Tab 2mg', 'total': 8},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Dalteparin Sod_Inj 25 000u/ml 0.72ml Pfs',
#   'total': 5},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Telmisartan_Tab 80mg', 'total': 25},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Lisinopril_Tab 20mg', 'total': 105},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Montelukast_Tab Chble 5mg S/F',
#   'total': 15},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Warfarin Sod_Tab 5mg', 'total': 88},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Longtec_Tab 60mg M/R', 'total': 5},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Dermovate_Crm 0.05%', 'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Azathioprine_Tab 25mg', 'total': 7},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Comfifast 10.75cm x 5m (Yellow)Stkntte E',
#   'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Acti-Fast 2-Way Stch 10.75cmx5m(Yell)Stk',
#   'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Fybogel_Gran Sach 3.5g Orange G/F S/F',
#   'total': 22},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'NovoPen 5 Blue 3ml 1u (1-60u) Hypod Reus',
#   'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Ibandronic Acid_Tab 150mg',
#   'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Citalopram Hydrob_Tab 40mg',
#   'total': 76},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Fluticasone/Salmeterol_Inh 100/50mcg 60D',
#   'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Adcal-D3_Tab Chble (Tutti-Frutti)',
#   'total': 175},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Stalevo_Tab 100mg/25mg/200mg',
#   'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Quinapril HCl_Tab 10mg', 'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Nitrofurantoin_Cap 50mg', 'total': 9},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Apixaban_Tab 5mg', 'total': 64},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Candesartan Cilexetil_Tab 4mg',
#   'total': 31},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Hypromellose_Eye Dps 0.5%',
#   'total': 13},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Erythromycin_Ethylsuc Susp 250mg/5ml S/F',
#   'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Monomax XL_Tab 60mg', 'total': 12},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Cyprote Acet_Tab 50mg', 'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Symbicort_Turbohaler 100mcg/6mcg (120 D)',
#   'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Valsartan_Cap 80mg', 'total': 12},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Topiramate_Cap 25mg', 'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Pregabalin_Cap 100mg', 'total': 7},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Flixotide_Evohaler 250mcg (120 D)',
#   'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Memantine HCl_Tab 10mg', 'total': 14},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Simvador_Tab 40mg', 'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Terbut Sulf_B/A Inha 500mcg (100 D)',
#   'total': 24},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Epilim Chrono 500_Tab 500mg C/R',
#   'total': 17},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'FastClix Lancets 0.3mm/30 Gauge',
#   'total': 15},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Water For Inj_5ml Amp', 'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Sevredol_Tab 10mg', 'total': 8},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Relvar Ellipta_Inha 92mcg/22mcg (30 D)',
#   'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Lyxumia_Inj 20mcg/0.2ml 3ml Pf Pen',
#   'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Letrozole_Tab 2.5mg', 'total': 36},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Pravastatin Sod_Tab 40mg',
#   'total': 102},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Timoptol-LA_Ophth Gel-Forming Soln 0.25%',
#   'total': 9},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Co-Beneldopa_Cap 12.5mg/50mg',
#   'total': 11},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Butec_Transdermal Patch 20mcg/hr',
#   'total': 22},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Rizatriptan_Orodisper Tab 10mg S/F',
#   'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Transtec_T/Derm Patch 52.5mcg/hr (30mg)',
#   'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Co-Dydramol_Tab 10mg/500mg',
#   'total': 33},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Terbinafine HCl_Tab 250mg',
#   'total': 21},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Co-Cyprindiol_Tab 2mg/35mcg',
#   'total': 8},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Premique_Low D Tab 0.3mg/1.5mg',
#   'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Qvar 50_Inha 50mcg (200 D)',
#   'total': 7},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Salivix Pastil (App)', 'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Isosorbide Mononit_Cap 25mg M/R',
#   'total': 56},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Isosorbide Mononit_Tab 60mg M/R',
#   'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Doxazosin Mesil_Tab 4mg M/R',
#   'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Coloplast_SenSura Mio Maxi Drnbl Bag S/C',
#   'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Calcichew D3 Fte_Tab Chble',
#   'total': 88},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Diprobase_Crm', 'total': 28},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Pioglitazone HCl_Tab 30mg',
#   'total': 10},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Efexor XL_Cap 150mg', 'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Spironol_Tab 50mg', 'total': 10},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Sando-K_Tab Eff 470mg', 'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Chlorhex Glucon_Mthwsh 0.2%',
#   'total': 8},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Zomorph_Cap 60mg', 'total': 10},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Rivaroxaban_Tab 15mg', 'total': 21},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Mirabegron_Tab 50mg M/R', 'total': 44},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Metronidazole_Oral Susp 200mg/5ml',
#   'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Ciprofloxacin_Tab 500mg', 'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Oilatum_Bath For', 'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Oramorph_Oral Soln 10mg/5ml',
#   'total': 23},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Diclofenac Sod_Tab E/C 50mg',
#   'total': 9},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Calcipotriol_Scalp Soln 50mcg/ml',
#   'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Bezafibrate_Tab 400mg M/R',
#   'total': 7},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Sertraline HCl_Tab 50mg',
#   'total': 290},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Etoricoxib_Tab 30mg', 'total': 6},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Lamotrigine_Tab 100mg', 'total': 32},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Mepore 7cm x 8cm Pfa + Adh Border Dress',
#   'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Zolmitriptan_Tab 2.5mg', 'total': 7},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Calc Carb_Tab Chble 1.5g (600mg) S/F',
#   'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Glimepiride_Tab 1mg', 'total': 7},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Micronor_Tab 350mcg', 'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Fultium-D3_Cap 800u', 'total': 25},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Atorvastatin_Tab 10mg', 'total': 296},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Aymes Shake_S/Pack Pdr', 'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Alfacalcidol_Cap 250ng', 'total': 14},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Melatonin_Tab 2mg M/R', 'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Chloramphen_Eye Oint 1%', 'total': 19},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Brinzolamide_Eye Dps 10mg/ml',
#   'total': 44},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Ibuprofen_Oral Susp 100mg/5ml S/F',
#   'total': 17},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Epilim 200_Tab E/C 200mg', 'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Ezetimibe_Tab 10mg', 'total': 90},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Hydrocort Acet/Fusidic Acid_Crm 1%/2%',
#   'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Digoxin_Tab 62.5mcg', 'total': 55},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'K-Y Lubri Jelly', 'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Alfacalcidol_Cap 500ng', 'total': 6},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Dosulepin HCl_Tab 75mg', 'total': 21},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Oxybutynin HCl_Tab 5mg', 'total': 28},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Nitromin_P/Spy 400mcg (180 D)',
#   'total': 34},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'L.IN.C_LINC-Flo Leg Bag 500ml Direct Inl',
#   'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Ins NovoRapid_Penfill 100u/ml 3ml Cart',
#   'total': 23},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Prucalopride_Tab 2mg', 'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Cinchocaine/Prednisolone_Oint 0.5%/0.19%',
#   'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Pantoprazole_Tab E/C 20mg',
#   'total': 27},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Moxonidine_Tab 200mcg', 'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Terbinafine HCl_Crm 1%', 'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Instant Carobel_Pdr', 'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Clindamycin HCl_Cap 150mg',
#   'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Cimetidine_Tab 400mg', 'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Viscotears_Liq Gel 2mg/g',
#   'total': 58},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Madopar_Cap 50mg/12.5mg', 'total': 7},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Linagliptin_Tab 5mg', 'total': 77},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Epilim 500_Tab E/C 500mg', 'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Rusch Brillant AquaFlate All Slc Foy Mal',
#   'total': 5},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Morph Sulf_Tab 10mg', 'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Risperidone_Tab 500mcg', 'total': 8},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Doxazosin Mesil_Tab 1mg', 'total': 44},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Juvela_G/F Mix Wte', 'total': 5},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Neditol XL_Cap 4mg', 'total': 16},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Irbesartan_Tab 150mg', 'total': 23},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Latanoprost/Timolol_Eye Dps 50mcg/5mg/ml',
#   'total': 17},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Ferr Glucon_Tab 300mg', 'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Atenolol_Tab 50mg', 'total': 223},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Etoricoxib_Tab 90mg', 'total': 26},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Unspecified Stkntte 10cm x 1m  Elasctd T',
#   'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Madopar_Cap 100mg/25mg', 'total': 7},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Repinex XL_Tab 8mg', 'total': 7},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Loperamide HCl_Tab 2mg', 'total': 16},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Rivaroxaban_Tab 20mg', 'total': 105},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Mezavant XL_Tab G/R 1.2g',
#   'total': 12},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Dutasteride_Cap 500mcg', 'total': 9},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Urea_Crm 10%', 'total': 6},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Lyrica_Cap 100mg', 'total': 15},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Ins NovoMix 30_FlexPen 100u/ml 3ml PfPen',
#   'total': 22},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Clenil Modulite_Inha 50mcg (200D)',
#   'total': 50},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Rivastigmine_Cap 6mg', 'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Unifine Pentips Needles Pen Inj Screw On',
#   'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Ibuprofen_Tab 400mg', 'total': 89},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'FreeStyle Optium (Reagent)_Strips',
#   'total': 19},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Nefopam HCl_Tab 30mg', 'total': 7},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Memantine HCl_Tab 20mg', 'total': 42},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Exemestane_Tab 25mg', 'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Gliclazide_Tab 80mg', 'total': 216},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Migraleve Complete_Tab', 'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Systane Hydroxypropyl Guar Eye Dps 0.8ml',
#   'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Blephasol_Lot', 'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Allevyn Gentle Border 7.5cm x 7.5cm Woun',
#   'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Lercanidipine HCl_Tab 10mg',
#   'total': 119},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Optive 0.5% Carmellose Eye Dps 10ml',
#   'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Hydromol Oint', 'total': 19},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Monomax SR 40_Cap 40mg', 'total': 6},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Moxonidine_Tab 300mcg', 'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Ins Humalog_KwikPen 100u/ml 3ml Pf Pen',
#   'total': 8},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Tadalafil_Tab 5mg', 'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Risperidone_Tab 1mg', 'total': 14},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Hyoscine Butylbrom_Inj 20mg/ml 1ml Amp',
#   'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Diclofenac Sod_Tab 75mg M/R',
#   'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Losartan Pot/Hydchloroth_Tab 100/12.5mg',
#   'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Enalapril Mal_Tab 5mg', 'total': 20},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Shortec_Cap 5mg', 'total': 23},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Salmeterol_Inha 25mcg (120 D) CFF',
#   'total': 30},
# ...
#   'total': 6},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Prednisolone Sod Phos_Eye Dps 0.5% Ud',
#   'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Exenatide_Inj 2mg Pdr + Dil PF Dev P/R',
#   'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Sinemet_Tab 12.5mg/50mg', 'total': 6},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Candesartan Cilexetil_Tab 32mg',
#   'total': 15},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Metoprolol Tart_Tab 100mg',
#   'total': 8},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Lyrica_Cap 50mg', 'total': 27},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'LoFric Non PVC Nelaton Male 8-22 (30-Pac',
#   'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Prednisolone_Tab Solb 5mg',
#   'total': 10},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Benzydamine HCl_Mthwsh 0.15% S/F',
#   'total': 10},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Simvastatin_Tab 80mg', 'total': 12},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Evorel Sequi_Patch', 'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Esomeprazole_Tab E/C 40mg',
#   'total': 10},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Raloxifene HCl_Tab 60mg', 'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Folic Acid_Tab 400mcg', 'total': 6},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Isotard 40 XL_Tab 40mg', 'total': 8},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Levomeprom HCl_Inj 25mg/ml 1ml Amp',
#   'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Warfarin Sod_Tab 3mg', 'total': 232},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Nicorandil_Tab 10mg', 'total': 144},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Estriol_Crm 0.01% + Applic',
#   'total': 29},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'GlucoRx FinePoint Ultra Needles Pen Inj',
#   'total': 58},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Dalteparin Sod_Inj 25 000u/ml 0.6ml Pfs',
#   'total': 8},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Dermol 600_Bath Emollient',
#   'total': 10},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Coracten SR_Cap 20mg', 'total': 5},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Levetiracetam_Tab 250mg', 'total': 18},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Co-Amoxiclav_Susp 250mg/62mg/5ml S/F',
#   'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Betameth Val_Oint 0.025% (1 in 4)',
#   'total': 5},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Eplerenone_Tab 50mg', 'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'FemSeven Conti_Patch', 'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Vildagliptin_Tab 50mg', 'total': 5},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Digoxin_Tab 125mcg', 'total': 88},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Escitalopram_Tab 20mg', 'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Metformin HCl_Tab 850mg', 'total': 26},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Mediven Plus Class 2 B/Knee Open Toe Lym',
#   'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Bimatoprost/Timolol_Eye Dps 300mcg/5mg',
#   'total': 10},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Clinitas Sod Hyaluronate Eye Dps 0.5ml U',
#   'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Betameth Val_Crm 0.025% (1 in 4)',
#   'total': 9},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Hydroxychlor Sulf_Tab 200mg',
#   'total': 75},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Fluticasone Prop_Inha 50mcg (120 D) CFF',
#   'total': 6},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Salbutamol_Inha 100mcg (200 D) CFF',
#   'total': 949},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Zerobase Crm (Appl)', 'total': 140},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Glucose_Gel 40%', 'total': 7},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Spironol_Tab 25mg', 'total': 110},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Timolol_Eye Dps 0.25%', 'total': 7},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Propranolol HCl_Cap 80mg M/R',
#   'total': 71},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Doxazosin Mesil_Tab 4mg',
#   'total': 108},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Hydromol_Bath & Shower Emollient',
#   'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Estradiol_Gel Sach 1mg/1g',
#   'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'GlucoRx Nexus (Reagent)_Strips',
#   'total': 190},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'BD Micro-Fine Ultra Needles Pen Inj Scre',
#   'total': 7},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Salts_Confidence Natural Drnbl Pch + C/B',
#   'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Amiodarone HCl_Tab 200mg',
#   'total': 17},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Trimethoprim_Tab 200mg', 'total': 103},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Buscopan_Tab 10mg', 'total': 12},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Valproic Acid_Tab G/R 500mg',
#   'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Class 11 Stnd C/Kt Thigh Stkn Elas Hose',
#   'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'GlucoRx Lancets 0.31mm/30 Gauge',
#   'total': 82},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Montelukast_Tab Chble 4mg S/F',
#   'total': 8},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Levothyrox Sod_Oral Soln 50mcg/5ml S/F',
#   'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Budesonide_Aq Nsl Spy 64mcg (120 D)',
#   'total': 10},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Olmesartan Medoxomil_Tab 10mg',
#   'total': 6},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Spiolto Respimat_Inha2.5/2.5mcg(60D)+Dev',
#   'total': 15},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Umeclidinium Brom_Inh 65mcg (30D)',
#   'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Adapalene_Crm 0.1%', 'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Desmopressin Acet_I/Nsl Spy 10mcg (60 D)',
#   'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Simvastatin_Tab 10mg', 'total': 78},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Dilzem SR 60_Cap 60mg', 'total': 10},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Glutafin Select_G/F Fresh Loaf Wte (Cut)',
#   'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Carbimazole_Tab 5mg', 'total': 15},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Miconazole_Oromucosal Gel 20mg/g S/F',
#   'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Epilim Chrono 200_Tab 200mg C/R',
#   'total': 13},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Neutrogena_T/Gel Therapeutic Shampoo 2%',
#   'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Sinemet-Plus_Tab 125mg', 'total': 13},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Ramipril_Cap 1.25mg', 'total': 171},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Dihydrocodeine Tart_Tab 120mg M/R',
#   'total': 21},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Bumetanide_Tab 1mg', 'total': 95},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Monopost_Eye Dps 50mcg/ml 0.2mlUd P/F',
#   'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Ramipril_Cap 10mg', 'total': 324},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Diazepam_Tab 5mg', 'total': 60},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Clenil Modulite_Inha 100mcg (200D)',
#   'total': 121},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Tiotropium/Olodaterol_Inha2.5/2.5mcg 60D',
#   'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Venlafaxine_Tab 225mg M/R',
#   'total': 11},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Stalevo_Tab 150mg/37.5mg/200mg',
#   'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Biotene Oralbalance Gel', 'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Dabigatran Etexilate_Cap 150mg',
#   'total': 21},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'OneTouch Ultra (Reagent)_Strips',
#   'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Tiopex_Gel Eye Dps 1mg/g 0.4g Ud',
#   'total': 7},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Nortriptyline_Tab 10mg', 'total': 11},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Aripiprazole_Tab 30mg', 'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Betameth Val/Clioquinol_Crm 0.1%/3%',
#   'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Lyrica_Cap 25mg', 'total': 17},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Pramipexole_Tab 520mcg M/R',
#   'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Duaklir Genuair_340mcg/12mcg (60D)',
#   'total': 37},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Prochlpzine Mal_Tab Buccal 3mg',
#   'total': 12},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Zopiclone_Tab 3.75mg', 'total': 79},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Lamotrigine_Tab 200mg', 'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Fenofibrate_Tab 160mg (Micronised)',
#   'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Pregabalin_Cap 300mg', 'total': 14},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Brinzolamide/Timolol_Eye Dps 10mg/5mg/ml',
#   'total': 21},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Depakote_Tab G/R 500mg', 'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Co-Codamol_Tab Eff 15mg/500mg S/F',
#   'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Fluoxetine HCl_Cap 20mg',
#   'total': 321},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Colchicine_Tab 500mcg', 'total': 21},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Co-Codamol_Tab 15mg/500mg',
#   'total': 84},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Isosorbide Mononit_Tab 10mg',
#   'total': 77},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'PVC Ring Pess 85-100mm 1.25cm Thick',
#   'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Vit_Cap', 'total': 15},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Alfacalcidol_Cap 1mcg', 'total': 9},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Clonidine HCl_Tab 25mcg', 'total': 23},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Clobet But_Crm 0.05%', 'total': 22},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Oilatum_Emollient', 'total': 24},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Meloxicam_Tab 15mg', 'total': 22},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Glimepiride_Tab 3mg', 'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Gaviscon Advance_Tab Chble Mint(Reckitt)',
#   'total': 20},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'E45_Emollient Bath Oil', 'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Glyceryl Trinit_Sub A/Spy 400mcg (180D)',
#   'total': 52},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Qvar 100_Inha 100mcg (200 D)',
#   'total': 26},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Xailin Carbomer Eye Gel 10g',
#   'total': 7},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Naproxen_Tab 500mg', 'total': 261},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Hydrocort_Crm 1%', 'total': 49},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Fluoxetine HCl_Cap 40mg', 'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Aspirin Disper_Tab 75mg',
#   'total': 1194},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Fluvastatin Sod_Cap 20mg', 'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Creon 10000_Cap E/C', 'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Xylomet HCl_Nsl Spy 0.1% 10ml',
#   'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Dansac_Non Sting Adh Remover A/Spy 50ml',
#   'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Ivabradine_Tab 5mg', 'total': 12},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Oilatum Plus_Bath Additive',
#   'total': 19},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Co-Trimoxazole_Tab 80mg/400mg',
#   'total': 5},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Aspirin_Tab E/C 75mg', 'total': 114},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Asacol_MR Tab E/C 800mg', 'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Coloplast_Conveen Optima Urisheath (Non',
#   'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Tildiem LA 200_Cap 200mg', 'total': 9},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Fusidic Acid_Crm 2%', 'total': 23},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Clopidogrel_Tab 75mg', 'total': 492},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'H & R_Proshield Foam & Spy Skin Cleanser',
#   'total': 6},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Adizem-XL_Cap 200mg', 'total': 10},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Buprenorphine_Patch 5mcg/hr (7day)',
#   'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Fludrocort Acet_Tab 100mcg',
#   'total': 25},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Ventolin_Accuhaler 200mcg (60 D)',
#   'total': 12},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Warfarin Sod_Tab 500mcg',
#   'total': 136},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Ins NovoRapid_PumpCart 100u/ml 1.6mlCart',
#   'total': 4},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Colecal & Calc_Tab 200u/750mg',
#   'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Erythromycin_Ethylsuc Susp 125mg/5ml',
#   'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'T & R Sod Bicarb Ear Dps 5% Ear Wax Soft',
#   'total': 10},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Risedronate Sod_Tab 35mg',
#   'total': 21},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Ins Levemir_FlexPen 100u/ml 3ml Pf Pen',
#   'total': 15},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Co-Careldopa_Tab 12.5mg/50mg',
#   'total': 12},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Modafinil_Tab 100mg', 'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Securon SR_Tab 240mg', 'total': 10},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Isosorbide Mononit_Cap 50mg M/R',
#   'total': 11},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Coloplast_Brava Adh Remover Spy 50ml',
#   'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Dimeticone/Benzalk Chlor_Crm 22%/0.1%',
#   'total': 8},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Dovonex_Oint 50mcg/1g', 'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Solifenacin_Tab 10mg', 'total': 30},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Betnovate_Oint 0.1%', 'total': 20},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Risperidone_Tab 3mg', 'total': 7},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Picato_Gel 150mcg/g', 'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Ibuprofen_Gel 5%', 'total': 9},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Bricanyl_Turbohaler 500mcg (100 D)',
#   'total': 9},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Co-Codamol_Cap 8mg/500mg', 'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Levetiracetam_Tab 500mg', 'total': 28},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Convatec_System 2 Belt', 'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Propranolol HCl_Tab 40mg',
#   'total': 44},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Bard Biocath Aquamatic H/Gel Foy P-Fill',
#   'total': 2},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Alphagan_Eye Dps 0.2%', 'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Seretide 250_Accuhaler 250mcg/50mcg(60D)',
#   'total': 22},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Ramipril_Cap 2.5mg', 'total': 408},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Clement Clarke AirZone Stnd Range Peak F',
#   'total': 10},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Longtec_Tab 20mg M/R', 'total': 18},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Ondansetron HCl_Tab 4mg', 'total': 5},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Class 1 Stnd C/Kt B/Knee Stkn Elas Hose',
#   'total': 9},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Convatec_Orabase Paste 30g',
#   'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Slozem 120_Cap 120mg', 'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Qvar 100_Autohaler 100mcg (200 D)',
#   'total': 3},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Biquelle XL_Tab 400mg', 'total': 2},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Tiotropium_Pdr For Inh Cap 18mcg',
#   'total': 197},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Losartan Pot_Tab 12.5mg', 'total': 20},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Amitriptyline HCl_Tab 25mg',
#   'total': 160},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Nutramigen 1 + LGG_Pdr', 'total': 4},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Atorvastatin_Tab 80mg', 'total': 186},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Fluticasone/Vilanterol_Inha 92/22mcg 30D',
#   'total': 5},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Mst Continus_Tab 5mg', 'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Co-Beneldopa_Cap 25mg/100mg',
#   'total': 11},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Hydromol Intensive_Crm 10%',
#   'total': 3},
#  {'post_code': 'YO16 4LZ',
#   'bnf_name': 'Fostair_Inh 100mcg/6mcg (120D) CFF',
#   'total': 388},
#  {'post_code': 'YO16 4LZ', 'bnf_name': 'Zerodouble Gel', 'total': 16},
#  ...]

# %%
from operator import itemgetter
get_total = itemgetter('total')
get_total(test_list[1])
# Out:
# 38

# %%
sorted(test_list, key=lambda x: get_total(x), reverse=True)[0]
# Out:
# {'post_code': 'YO16 4LZ', 'bnf_name': 'Aspirin Disper_Tab 75mg', 'total': 1194}

# %%
max_item_by_post = []
groups = list(total_items_by_post.values())
for group in groups:
    max_total = sorted(group, key=itemgetter('total'), reverse=True)[0]
    max_item_by_post.append(max_total)

# %%
max_item_by_post[0]
# Out:
# {'post_code': 'WN2 5NG', 'bnf_name': 'Omeprazole_Cap E/C 20mg', 'total': 939}

# %% [markdown]
# In order to express the item totals as a proportion of the total amount of items prescribed across all `'bnf_name'` in a postal code, we'll need to use the total items prescribed that previously calculated as `items_by_post`. Calculate the proportions for the most common `'bnf_names'` for each postal code. Format your answer as a list of tuples: `[(post_code, bnf_name, total)]`

# %%
items_by_post = []
for name, group in list(group_by_field(joined, ('post_code',)).items()):
    item_sum = sum(dict_['items'] for dict_ in group)
    name = name[0]
    my_tuple = (name,item_sum)
    items_by_post.append(my_tuple)

# %%
items_by_post.sort()

# %%
dict(items_by_post)
# Out:
# {'B11 4BW': 20673,
#  'B18 7AL': 19001,
#  'B21 9RY': 29103,
#  'B23 6DJ': 24859,
#  'B70 7AW': 36531,
#  'BB11 2DL': 34356,
#  'BB2 1AX': 28254,
#  'BB3 1PY': 54514,
#  'BB4 5SL': 29388,
#  'BB7 2JG': 44585,
#  'BB8 0JZ': 54380,
#  'BB9 7SR': 38224,
#  'BD3 8QH': 21010,
#  'BH18 8EE': 39413,
#  'BH23 3AF': 32545,
#  'BL1 8TU': 26132,
#  'BL3 5HP': 27147,
#  'BL9 0NJ': 32062,
#  'BL9 0SN': 35275,
#  'CB9 8HF': 51337,
#  'CH1 4DS': 34915,
#  'CH65 6TG': 25090,
#  'CT11 8AD': 44358,
#  'CV1 4FS': 37210,
#  'CW1 3AW': 64104,
#  'CW5 5NX': 38797,
#  'CW7 1AT': 43164,
#  'DA1 2HA': 26075,
#  'DA11 8BZ': 24090,
#  'DN22 7XF': 43091,
#  'DN34 4GB': 48013,
#  'FY2 0JG': 69118,
#  'FY4 1TJ': 62886,
#  'FY5 2TZ': 44258,
#  'FY7 8GU': 34473,
#  'GL1 3PX': 38120,
#  'GL50 4DP': 74822,
#  'GU9 9QS': 32131,
#  'HA0 4UZ': 22755,
#  'HA3 7LT': 32113,
#  'HG1 5AR': 32684,
#  'HU7 4DW': 49107,
#  'KT14 6DH': 26758,
#  'KT6 6EZ': 38975,
#  'L31 0DJ': 32065,
#  'L36 7XY': 22965,
#  'L5 0QW': 24676,
#  'L7 6HD': 42569,
#  'LA1 1PN': 47335,
#  'LE10 1DS': 49335,
#  'LE18 2EW': 37144,
#  'LE5 3GH': 28654,
#  'LN2 2JP': 46173,
#  'LS9 9EF': 48051,
#  'M11 4EJ': 23166,
#  'M26 2SP': 37718,
#  'M30 0NU': 25597,
#  'M35 0AD': 37632,
#  'ME8 8AA': 25257,
#  'N9 7HD': 30706,
#  'NE10 9QG': 39882,
#  'NE24 1DX': 50491,
#  'NE37 2PU': 57500,
#  'NE38 7NQ': 52803,
#  'NG7 3GW': 17698,
#  'NG7 5HY': 24903,
#  'NN16 8DN': 50771,
#  'NW10 8RY': 21553,
#  'OL1 1NL': 41046,
#  'OL11 1DN': 21567,
#  'OL4 1YN': 24687,
#  'OL9 7AY': 28394,
#  'PL7 1AD': 65051,
#  'RM3 9SU': 25476,
#  'S63 9EH': 34787,
#  'S65 1DA': 71683,
#  'S74 9AF': 55305,
#  'SE1 6JP': 45030,
#  'SE15 5LJ': 15258,
#  'SK11 6JL': 110071,
#  'SK6 1ND': 28313,
#  'SM3 8EP': 24965,
#  'SM6 0HY': 46016,
#  'SR4 7XF': 49843,
#  'SR5 2LT': 44895,
#  'SS0 7AF': 21569,
#  'SS13 3HQ': 38513,
#  'SS8 0JA': 45848,
#  'SS9 5UU': 26095,
#  'ST1 4PB': 24227,
#  'ST3 6AB': 38705,
#  'ST8 6AG': 34516,
#  'TN24 0GP': 16955,
#  'TN34 1BA': 47440,
#  'TR1 2JA': 40194,
#  'TS1 2NX': 47623,
#  'TS10 4NW': 45161,
#  'TS17 0EE': 68388,
#  'TS23 2DG': 31646,
#  'TS24 7PW': 58207,
#  'TS3 6AL': 51402,
#  'TW13 4GU': 19584,
#  'TW3 3LN': 40141,
#  'TW8 8DS': 26941,
#  'W10 6DZ': 16264,
#  'WA10 2DJ': 40394,
#  'WA7 1AB': 41314,
#  'WA9 1LN': 29644,
#  'WD18 0JP': 21034,
#  'WF13 1HN': 25456,
#  'WN2 5NG': 22795,
#  'WN3 5HL': 31149,
#  'WN7 1HR': 29076,
#  'WN7 2PE': 23130,
#  'WS10 8SY': 12598,
#  'WS3 3JP': 35242,
#  'WV13 2DR': 33844,
#  'YO16 4LZ': 52032}

# %%
items_by_region = []

for item in max_item_by_post:
    numerator = item['total']
    denominator = dict(items_by_post)[item['post_code']]
    proportion = numerator / denominator
    result = (item['post_code'], item['bnf_name'], proportion)
    items_by_region.append(result)

# %%
items_by_region[0]
# Out:
# ('WN2 5NG', 'Omeprazole_Cap E/C 20mg', 0.04119324413248519)

# %%
items_by_region = sorted(items_by_region)[:100 ]

# %%
#items_by_region = [('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247)] * 100

# %%
items_by_region[:1]
# Out:
# [('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.03415082474725487)]

# %%
grader.score.pw__items_by_region(items_by_region)
# Out:
# ==================
# Your score:  1.0
# ==================

# %% [markdown]
# *Copyright &copy; 2017 The Data Incubator.  All rights reserved.*
